# %% [markdown]
# # 텍스트 마이닝(Text Mining)

# %% [markdown]
# ## 텍스트 마이닝(Text Mining)
# - 웹페이지, 블로그, 이메일, 뉴스 기사 등 텍스트 데이터로부터 유용한 정보를 추출하는 과정
# - 텍스트 데이터로부터 정보를 자동으로 추출하도록 구성
# - 텍스트 분석에는 정보 검색, 어휘 분석을 통한 단어 빈도 분포 연구, 패턴 인식, 정보 추출, 연관 분석 등 데이터 마이닝 기술이 포함
# - 근본적인 목표는 자연어 처리, 다양한 유형의 알고리즘 및 분석 방법을 적용하여 정제되지 않은 텍스트 데이터를 분석용 데이터(관계형 데이터)로 변환하는 것

# %% [markdown]
# ## 자연어 처리(Natural Language Processing)
# - 자연어란 사람이 일상생활에서 사용하는 언어를 의미
# - 자연어 처리는 자연어의 의미를 분석하여 컴퓨터가 처리할 수 있도록 하는 작업을 의미
# - 자연어 처리는 텍스트 분류 작업, 음성 인식, 내용 요약, 번역, 사용자의 감성 분석, 챗봇, 텍스트 군집화와 같은 기능에 사용되는 분야

# %% [markdown]
# ### 필요 프레임워크와 라이브러리
# - 아나콘다에는 기본적으로 Numpy, Pandas, Jupyter notebook, scikit-learn, matplotlib, seaborn 등이 설치되어 있음

# %% [markdown]
# ### 자연어 처리 라이브러리 KoNLPy, NLTK설치하기
# - 코엔엘파이(KoNLPy) : 한국어 자연어 처리를 위한 라이브러리
# - 엔엘티케이(NLTK) : 영어 자연어 처리를 위한 라이브러리.

# %% [markdown]
# #### KoNLPy 설치
# - JDK와 JPype를 설치하여 완료

# %%
# !pip install konlpy
# Out:
# Requirement already satisfied: konlpy in c:\users\sdedu\anaconda3\lib\site-packages (0.6.0)
# Requirement already satisfied: JPype1>=0.7.0 in c:\users\sdedu\anaconda3\lib\site-packages (from konlpy) (1.5.0)
# Requirement already satisfied: lxml>=4.1.0 in c:\users\sdedu\anaconda3\lib\site-packages (from konlpy) (4.9.3)
# Requirement already satisfied: numpy>=1.6 in c:\users\sdedu\anaconda3\lib\site-packages (from konlpy) (1.26.4)
# Requirement already satisfied: packaging in c:\users\sdedu\anaconda3\lib\site-packages (from JPype1>=0.7.0->konlpy) (23.1)

# %%
import konlpy

# %%
konlpy.__version__
# Out:
# '0.6.0'

# %%
import jpype

# %%
jpype.__version__
# Out:
# '1.5.0'

# %% [markdown]
# ### 판다스(Pandas), 넘파이(Numpy), 맷플롯립(matplotlib) 설치

# %%
# !pip install pandas
# !pip install matplotlib
# Out:
# Requirement already satisfied: pandas in c:\users\sdedu\anaconda3\lib\site-packages (2.1.4)
# Requirement already satisfied: numpy<2,>=1.23.2 in c:\users\sdedu\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\sdedu\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sdedu\anaconda3\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\sdedu\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\sdedu\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: matplotlib in c:\users\sdedu\anaconda3\lib\site-packages (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sdedu\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\sdedu\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sdedu\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\sdedu\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy<2,>=1.21 in c:\users\sdedu\anaconda3\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\sdedu\anaconda3\lib\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\sdedu\anaconda3\lib\site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\sdedu\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sdedu\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\sdedu\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import pandas as pd # 판다스 임포트

# %%
import numpy as np # 넘파이 임포트

# %%
import matplotlib as mpl # 맷플롯립 임포트

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# ### 머신러닝 워크플로우 (Machine Learning Workflow)
# 1. 머신러닝 데이터 수집
#  - 머신러닝 워크플로우에서 데이터 수집은 매우 중요한 과정
#  - 데이터 수집 중, 수집한 데이터의 품질로 프로젝트의 잠재적 유용성과 정확도를 정의할 수 있음
#  - 데이터 수집을 위해, 자원을 식별하고 식별된 자원으로 데이터를 통합하여 단일 데이터셋으로 변경할 필요가 있음
#  - 이 데이터셋은 사물인터넷 센서에서 데이터를 스트리밍하거나, 오픈 데이터 소스를 다운로드하거나, 여러 파일, 로그, 또는 미디어로부터 데이터 레이크를 구성하는 것을 의미
#
# 2. 데이터 전처리
#  - 데이터가 수집되면 전처리가 필요함
#  - 전처리 과정은 정제, 검증, 사용가능한 데이터셋으로 형변환 등을 포함
#  - 단일 소스 데이터를 수집한 경우 간단한 과정으로 처리가 가능
#  - 그러나, 여러 개의 데이터를 수집한 경우, 데이터 형식이 일치 하는지 동일하게 신뢰할 수 있는지 확인해야하고 잠재적 중복 요소를 제거해야 함
#
# 3. 데이터셋 구축
#  - 이 단계는 데이터를 3개의 데이터셋으로 분할하는 과정이 포함됨 : 훈련, 검증, 테스트
#  - Training set : 알고리즘을 처음 훈련시키는데 사용하고 정보처리 방법을 학습. 이 데이터셋은 파라미터를 통한 모델 분류를 정의
#  - Validation set : 모델의 정확도에 대해 평가하기 위해 사용. 이 데이터셋은 모델 파라미터를 미세하게 조정하기 위해 사용
#  - Test set : 모델의 정확도와 성능에 대해 평가하기 위해 사용. 이 데이터셋은 모델에서 잘못된 훈련이나 특정 이슈를 찾기 위해 사용
#
# 4. 훈련 및 정제
#  - 알고리즘에 훈련 세트를 제공하여 분류에 사용되는 적절한 매개변수와 특징을 훈련할 수 있음
#  - 훈련이 완료되면 유효성 검사 데이터셋을 사용하여 모델을 정제할 수 있음
#  - 이 정제과정은 변수 수정 및 삭제가 포함될 수 있고, 허용 가능한 정확도 수준에 도달 할 때까지 모델 별 설정(하이퍼 매개 변수)을 조정하는 프로세스가 포함됨
#
# 5. 머신러닝 평가
#  - 허용 가능한 하이퍼 파라미터 세트를 찾고 모델 정확도를 최적화 한 후 모델을 테스트 할 수 있음
#  - 테스트는 테스트 데이터 세트를 사용하며 모델이 정확한 기능을 사용하고 있는지 확인하기위한 것
#  - 확인 후 받은 피드백에 따라 정확도를 높이고 출력 설정을 조정하거나 필요에 따라 모델을 배포하기 위해 모델 학습으로 돌아갈 수 있음

# %% [markdown]
# ## 데이터 수집(Data Acquisition)
# - 텍스트 마이닝에서는 일반적으로 정제되지 않은 데이터(비정형 데이터)를 수집하여 정제된 데이터(정형 데이터)로 변환하는 과정을 거침
# - 정형 데이터는 일반적으로 로우와 컬럼을 갖는 테이블 형식의 데이터로 DataBase, csv, excel 데이터 등이 존재함. 흔히 구조화된 데이터(Structured Data)라고 부름
# - 비정형 데이터는 구조화된 데이터가 아닌 데이터(Unstructured Data)를 의미하며, 텍스트, 그림, 영상 등이 있음.
# - 반정형 데이터(Semi-Structured Data)는 테이블과 같은 형식은 아니지만 key-value 특성과 메타 데이터 특성을 갖는 데이터를 의미하며, xml, html, json 등이 있음
# - 이번 챕터에서는 비정형 데이터를 수집하는 웹 크롤링에 대해 실습

# %%
# 웹 크롤링을 위한 라이브러리 설치
# !pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\users\jhmoc\anaconda3\lib\site-packages (4.11.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\jhmoc\anaconda3\lib\site-packages (from beautifulsoup4) (2.3.2.post1)

# %%
from urllib.request import urlopen # 웹에서 데이터를 가져오는 라이브러리
from bs4 import BeautifulSoup # html 데이터 parsing을 위한 라이브러리
from urllib import parse # 한글 파싱을 위한 라이브러리
# 네이버 뉴스기사에서 "빅데이터"를 검사
# 기사 제목 데이터만 추출하기
query = parse.quote("울산") # 한글 데이터 입력을 위해 데이터 파싱
start = str(1) # 뉴스 게시물 시작 번호를 의미. ex) 1페이지 = 1, 2페이지 = 11, 3페이지 = 21
url = "https://search.naver.com/search.naver?where=news&sm=tab_jum&query=" + query
html = urlopen(url)  
data = BeautifulSoup(html, "html.parser")

print(type(data))
print(data)
# Out:
# <class 'bs4.BeautifulSoup'>
# <!DOCTYPE html>
#  <html lang="ko"><head> <meta charset="utf-8"/> <meta content="always" name="referrer"/> <meta content="telephone=no,address=no,email=no" name="format-detection"/> <meta content="width=device-width,initial-scale=1.0,maximum-scale=2.0" name="viewport"/> <meta content="울산 : 네이버 뉴스검색" property="og:title"> <meta content="https://ssl.pstatic.net/sstatic/search/common/og_v3.png" property="og:image"/> <meta content="'울산'의 네이버 뉴스검색 결과입니다." property="og:description"/> <meta content="'울산'의 네이버 뉴스검색 결과입니다." lang="ko" name="description"/> <title>울산 : 네이버 뉴스검색</title> <link href="https://ssl.pstatic.net/sstatic/search/favicon/favicon_191118_pc.ico" rel="shortcut icon"/> <link href="https://ssl.pstatic.net/sstatic/search/opensearch-description.https.xml" rel="search" title="Naver" type="application/opensearchdescription+xml"><script> if (top.frames.length!=0 || window!=top) window.open(location, "_top"); </script><link href="https://ssl.pstatic.net/sstatic/search/pc/css/search1_230629.css" rel="stylesheet" type="text/css"/> <link href="https://ssl.pstatic.net/sstatic/search/pc/css/search2_230629.css" rel="stylesheet" type="text/css"/> <link href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_autocomplete_220526.css" rel="stylesheet" type="text/css"/><script> naver = window.naver || {}; naver.search = naver.search || {}; naver.search.abt_param = ""; </script><script> naver = window.naver || {}; naver.search = naver.search || {}; naver.search.error = (function () { var errorList = Array() ; return { add : function (s) { errorList.push(s) ; }, clear : function () { delete errorList ; }, get : function (s) { return errorList ; }, getString : function (d) { if (typeof d === 'undefined') d = '|' ; return errorList.join(d) ; } } })(); function nx_add_event_handler (event, func) { $Fn(func).attach(document, event) ; } function bt(id, after) { document.getElementById(id).src = after; } function document_write (s) { document.write(s) ; } </script><script> var _nx_js_load = (function () { var scrs = {} ; return function (script, callback) { scrs[script] = {} ; scrs[script].domscript = document.createElement('script'); scrs[script].domscript.src = script ; if (callback) scrs[script].callback = (callback instanceof Array) ? callback : [callback]; scrs[script].domscript.onloadDone = false; scrs[script].domscript.onload = function() { scrs[script].domscript.onloadDone = true; if (scrs[script].callback) { for (var i = 0; i < scrs[script].callback.length; i++) { scrs[script].callback[i]() ; } } scrs[script].domscript.onload = scrs[script].domscript.onreadystatechange = null; } ; scrs[script].domscript.onreadystatechange = function() { if ( ("loaded" === scrs[script].domscript.readyState || "complete" === scrs[script].domscript.readyState) && !scrs[script].domscript.onloadDone ) { scrs[script].domscript.onload(); } } ; document.getElementsByTagName('head')[0].appendChild(scrs[script].domscript); }; })() ; var nx_js_defer_load = (function() { var info = {} ; return function(scrname, callback, t) { var nx_load_once = (function() { return function(scrname) { if (info[scrname].t > 0) setTimeout(function() { _nx_js_load(scrname, info[scrname].callback) ; }, t) ; else _nx_js_load(scrname, info[scrname].callback) ; } ; })(); if (t < 0) t = 0 ; if (info[scrname]) { n = info[scrname].length; for (var i = 0; i < n; i++) { if (info[scrname][i] == callback) return ; } if (t < info[scrname].t) info[scrname].t = t ; } else { info[scrname] = {} ; info[scrname].callback = [] ; info[scrname].t = t ; jindo.$Fn(function() { nx_load_once(scrname) ; }).attach(window, "load") ; } info[scrname].callback.push(callback) ; }; })(); function nx_js_lazyload(scripts, onload, is_serial) { if (!(scripts instanceof Array)) { scripts = [scripts]; } if (is_serial) { function load_next() { if (scripts.length == 0) { onload(); return; } _nx_js_load( scripts.shift(), load_next ) ; } load_next(); } else { var load_check = function() { var num_js = scripts.length; return function() { num_js--; ...

# %%
data.head.title # html의 title 태그 데이터 출력
# Out:
# <title>울산 : 네이버 뉴스검색</title>

# %%
data.head.find("meta", {"name" : "referrer"})
# meta 태그의 name = "referrer"인 태그 전체를 출력
# Out:
# <meta content="always" name="referrer"/>

# %%
data.head.find("meta", {"name" : "referrer"}).get('content')
# meta 태그의 name = "referrer"인 태그에서 content 값을 출력
# Out:
# 'always'

# %%
list = []
for title in data.find_all("a", {"class":"news_tit"}):
    list.append(title.text)
    print(title.text) # class="news_tit"인 a 태그의 내용을 출력(뉴스 제목 데이터 추출)
# Out:
# 수경 찾아주려다가···울산 진하해수욕장 레저축제 안전요원 사망
# 해수욕장 첫날…울산 레저축제서 20대 안전요원 사망
# 생기연, 미세먼지·악취 동시에 제거한다…울산서 실증 착수
# 울산 고래문화특구 만족도 조사서 95.5% '만족'
# 울산 해수욕장 일본 오염수 방류 시 매주 방사능 검사
# 장마 주춤 무더위…부산 울산 경남 낮 최고 28~34도
# 레저축제 열리던 울산 해수욕장서 20대 안전관리요원 숨져
# 수경 찾아주던 20대 안전요원 그만…울산 해양축제 전면 취소
# 국민의힘, 이번 주 대구·울산·부산 찾아 예산정책협의회 개최
# 울산 북구 동해남부선 폐철도 ‘도시숲’으로 변신

# %%
print(list[2])
# Out:
# 생기연, 미세먼지·악취 동시에 제거한다…울산서 실증 착수

# %% [markdown]
# #### 퀴즈
# - 크롤링 환경을 구축하여 서울시 게시판에 있는 데이터 중 title 태그의 값을 가져와서 출력하기

# %%
# 페이지 번호 1 ~ 10번까지의 기사 제목를 리스트에 저장하기
titleList = []
query = parse.quote("빅데이터")
for i in range(1, 500, 10): # 1. start 번호가 1, 11, 21, ... , 91이 되도록 범위 설정
    start = str(i)
    # 2. 각 start 번호 별로 데이터 추출
    url = "https://search.naver.com/search.naver?&where=news&query="+query+"&sm=tab_pge&sort=0&photo=0&field=0&reporter_article=&pd=0&ds=&de=&docid=&nso=so:r,p:all,a:all&mynews=0&cluster_rank=33&start="+start+"&refresh_start=0"
    html = urlopen(url) 
    # 3. 가져온 데이터 html로 파싱
    data = BeautifulSoup(html, "html.parser")
    # 4. 파싱된 html에서 title 데이터만 추출하여 저장
    for title in data.find_all("a", {"class":"news_tit"}):
        titleList.append(title.text)

# %%
titleList[1]
# Out:
# '창원시, 빅데이터 공모전 개최…9월 말까지 접수'

# %% [markdown]
# ## 텍스트 전처리(Text Preprocessing)
# - 텍스트 전처리는 용도에 맞게 텍스트를 사전에 처리하는 과정
# - 필요한 텍스트만 용도에 맞게 처리해야 데이터를 사용할 수 있음
# - 크롤링 등으로 얻어낸 코퍼스(corpus, 말뭉치) 데이터는 용도에 맞게 전처리 과정을 거쳐야 함
# - 이 과정은 토큰화, 정제, 정규화 등을 포함

# %% [markdown]
# ### 토큰화(Tokenization)
# - 주어진 코퍼르에서 토큰이라고 불리는 단위로 나누는 작업을 토큰화라고 함
# - 토큰의 단위는 상황에 따라 다르지만, 보통 의미있는 단위로 토큰을 정의

# %% [markdown]
# #### 한국어 토큰화 실습
# - 형태소(morpheme)란 뜻을 가진 가장 작은 말의 단위를 의미
# - 한국어 토큰화에는 형태소 개념에 대한 이해가 필요하며, 형태소에는 자립 형태소와 의존 형태소가 존재
# - 자립 형태소 : 접사, 어미, 조사와 상관없이 자립하여 사용할 수 있는 형태소. 체언(명사, 대명사, 수사), 수식언(관형사, 부사), 감탄사 등이 있음
# - 의존 형태소 : 다른 형태소와 결합하여 사용되는 형태소. 접사, 어미, 조사, 어간 등이 있음
# - 예시) 둘리가 집을 나갔다.
#  - 자립 형태소 : 둘리, 집
#  - 의존 형태소 : -가, -을, 나-, -갔, -다
# - 형태소 토큰화를 통해 의미있는 단어를 추출
# - 한국어 자연어 처리는 KoNLPy(코엔엘파이) 패키지를 사용
# - 코엔엘파이 형태소 분석기는 Okt(Open Korea Text), 메캅(Mecab), 코모란(Komoran), 한나눔(Hannanum), 꼬꼬마(Kkma)가 있음

# %%
from konlpy.tag import Okt # Open Korea Text 라이브러리 임포트   
okt=Okt()  
# morphs : 형태소 추출
# pos : 품사 태깅(Par-of-speech tagging)
# nouns : 명사 추출
print(okt.morphs("안녕하세요. 날씨가 좋네요. 다같이 즐겁게 코딩합시다!!"))
# Out:
# ['안녕하세요', '.', '날씨', '가', '좋네요', '.', '다', '같이', '즐겁게', '코딩', '합시다', '!!']

# %%
print(okt.pos("안녕하세요. 날씨가 좋네요. 다같이 즐겁게 코딩합시다!!"))
# Out:
# [('안녕하세요', 'Adjective'), ('.', 'Punctuation'), ('날씨', 'Noun'), ('가', 'Josa'), ('좋네요', 'Adjective'), ('.', 'Punctuation'), ('다', 'Noun'), ('같이', 'Josa'), ('즐겁게', 'Adjective'), ('코딩', 'Noun'), ('합시다', 'Verb'), ('!!', 'Punctuation')]

# %%
print(okt.nouns("안녕하세요. 날씨가 좋네요. 다같이 즐겁게 코딩합시다!!"))
# Out:
# ['날씨', '다', '코딩']

# %%
# 네이버 빅데이터 검색 결과 데이터에서 명사만 추출하기
titleNounsList = []
for title in titleList:
    list = okt.nouns(title)
    for l in list:
        titleNounsList.append(l)
        print(l)
# Out:
# 용인시
# 각종
# 데이터
# 곳
# 빅데이터
# 플랫폼
# 창원시
# 빅데이터
# 공모전
# 개최
# 말
# 접수
# 취업
# 걱정
# 명품
# 학교
# 선일
# 빅데이터
# 고등학교
# 포항시
# 빅데이터
# 기반
# 대기
# 환경
# 개선
# 교통
# 약자
# 장애인
# 동권
# 향상
# 도보
# 내비게이션
# 빅데이터
# 구축
# 포항시
# 빅데이터
# 기반
# 대기
# 환경
# 대응
# 시스템
# 구축
# 예능
# 프로그램
# 빅데이터
# 분석
# 결과
# 위
# 유
# 퀴즈
# 더
# 블럭
# 위
# 런닝맨
# 위
# 엔비디아
# 땅
# 총
# 기업
# 또
# 홍키
# 명
# 바이오
# 빅데이터
# 구축
# 사업
# 예비
# 타당성
# 조사
# 통과
# 창원시
# 빅데이터
# 공모전
# 모집
# 신세계
# 앤
# 빅데이터
# 기술
# 그룹
# 사
# 시너지
# 창
# 엔비디아
# 땅
# 총
# 기업
# 또
# 홍키
# 바이오
# 빅데이터
# 구축
# 사업
# 타
# 통과
# 명
# 바이오
# 빅데이터
# 구축
# 사업
# 예비
# 타당성
# 조사
# 통과
# 핫
# 관광지
# 옥천
# 읍
# 빅데이터
# 진단
# 협력
# 사
# 랜섬
# 웨어
# 해킹
# 피해
# 안내면
# 데이터
# 공개
# 주
# 황의조
# 여론
# 충격
# 사생활
# 영상
# 보
# 딥
# 데이터
# 바이오
# 빅데이터
# 구축
# 단계
# 추진
# 게시판
# 심평원
# 빅데이터
# 개방
# 포털
# 전면
# 개편
# 상명대
# 빅데이터
# 전문
# 기업
# 이씨
# 마이너
# 산학
# 협력
# 협약
# 티
# 헬
# 스케
# 자궁경부암
# 영상
# 진단
# 플랫폼
# 공개
# 데이터
# 민주화
# 오픈소스
# 노
# 코드
# 가야
# 데이터
# 커머스
# 콕
# 배송비
# 전면
# 무료
# 창원
# 특례시
# 창원
# 빅데이터
# 공모전
# 에어컨
# 브랜드
# 평판
# 빅데이터
# 분석
# 결과
# 위
# 삼성
# 전자
# 위
# 전자
# 위
# 해수부
# 스마트
# 양식
# 빅데이터
# 센터
# 구축
# 지자체
# 공모
# 빅데이터
# 기반
# 저작권
# 침해
# 종합
# 대응
# 시스템
# 구축
# 사업
# 추진
# 건보
# 빅데이터
# 기반
# 척수
# 손상
# 합병증
# 현황
# 보고서
# 발표
# 하이엔드
# 아파트
# 브랜드
# 평판
# 빅데이터
# 분석
# 결과
# 예능
# 방송인
# 브랜드
# 평판
# 빅데이터
# 분석
# 결과
# 위
# 유재석
# 위
# 탁재훈
# 위
# 데이터
# 플랫폼
# 업계
# 확산
# 속
# 크로스
# 플랫폼
# 지원
# 급
# 물살
# 서울
# 사이버대
# 빅데이터
# 센터
# 빅데이터
# 정보보호
# 학과
# 인공
# 지능
# 팩토리
# 김태
# 김해시
# 행안부
# 빅데이터
# 분석
# 모델
# 공모
# 사업
# 선정
# 정부
# 공언
# 공공
# 의료
# 데이터
# 개방
# 개인
# 정보보호
# 대전
# 상의
# 특허
# 빅데이터
# 기반
# 미래
# 유망
# 기술
# 세미나
# 개최
# 브랜드
# 평판
# 간편
# 결제
# 빅데이터
# 분석
# 결과
# 위
# 네이버
# 페이
# 위
# 대전
# 상의
# 특허
# 빅데이터
# 기반
# 미래
# 유망
# 기술
# 제시
# 조달청
# 내달
# 조달
# 빅데이터
# 활용
# 아이디어
# 공모
# 서울시
# 택배
# 송장
# 기반
# 생활
# 물류
# 데이터
# 공개
# 명
# 의료
# 바이오
# 빅데이터
# 장성
# 클라우드
# 데이터
# 센터
# 유치
# 가동
# 데이터
# 수집
# 권리
# 개인정보
# 보호
# 균형
# 신세계
# 앤
# 신세계
# 그룹
# 빅데이터
# 개발자
# 컨퍼런스
# 개
# 광진구
# 빅데이터
# 분석
# 공모
# 시상식
# 개최
# 청년
# 발언
# 의료
# 바이오
# 빅데이터
# 개방
# 앞
# 의료
# 기술
# 개발
# 빅데이터
# 쇼
# 이스트소프트
# 준비
# 휴먼
# 기술
# 호평
# 리츠
# 브랜드
# 평판
# 빅데이터
# 분석
# 결과
# 바이오
# 전략
# 자산
# 빅데이터
# 구축
# 장성군
# 클라우드
# 데이터
# 센터
# 구축
# 광주시
# 데이터
# 플랫폼
# 등
# 개
# 기업
# 업무
# 협약
# 경기도
# 위기
# 징후
# 빅데이터
# 활용
# 복지
# 사각
# 지대
# 명
# 지원
# 한수정
# 종자
# 정보
# 빅데이터
# 기업
# 개방
# 바이오
# 산업
# 육성
# 선도
# 건설
# 빅데이터
# 스타트업
# 프리
# 투자
# 유치
# 고흥군
# 순천대
# 스마트
# 혁신
# 밸리
# 빅데이터
# 센터
# 운영
# 위탁
# 금융
# 공공기관
# 브랜드
# 빅데이터
# 분석
# 결과
# 경남
# 미래
# 교육
# 빅데이터
# 인공
# 지능
# 활용
# 수업
# 혁신
# 사례
# 눈길
# 기획
# 빅데이터
# 접목
# 렌탈
# 플랫폼
# 통운
# 디지털
# 유통
# 대전
# 참가
# 빅데이터
# 기반
# 물류
# 플랫폼
# 빅데이터
# 사회
# 기업
# 지원
# 신한카드
# 경기도
# 주식회사
# 협력
# 건강
# 기능
# 식품
# 상장
# 기업
# 브랜드
# 평판
# 빅데이터
# 분석
# 톱
# 진주
# 인공
# 지능
# 빅데이터
# 활용
# 생활
# 밀착
# 스마트
# 도시
# 로
# 샘
# 가구
# 상장
# 기업
# 브랜드
# 평판
# 빅데이터
# 분석
# 선두
# 평판
# 지수
# 하락
# 빅데이터
# 전남
# 이슈
# 관광
# 광양
# 한국
# 노총
# 영암
# 아우토반
# 도로공사
# 스마트
# 건설
# 데이터
# 디지털
# 플랫폼
# 기술
# 세미나
# 개최
# 고창군
# 행안부
# 빅데이터
# 표준
# 분석
# 모델
# 정립
# 사업
# 공모
# 선정
# 엑스
# 로그
# 카카오
# 클라우드
# 데이터
# 관
# 복제
# 솔루션
# 등록
# 약국
# 건기
# 분
# 상담
# 알고리즘
# 빅데이터
# 더
# 빅데이터
# 쇼
# 챗
# 붐
# 타고
# 성황
# 현대
# 에너지
# 솔루션
# 전력
# 중개
# 사업
# 개시
# 태양광
# 발전소
# 빅데이터
# 활용
# 계명대
# 동산의료원
# 스마트
# 플랫폼
# 빅데이터
# 서비스
# 구축
# 착수
# 소상
# 공인
# 디지털
# 전환
# 촉진
# 빅데이터
# 플랫폼
# 구축
# 본격
# 핏
# 데이터
# 삼성
# 화재
# 애니
# 핏
# 플러스
# 새
# 광고
# 알
# 에스
# 한국
# 관광
# 데이터
# 랩
# 관광
# 수요
# 데이터
# 제공
# 국가
# 바이오
# 빅데이터
# 연구개발
# 전면
# 개방
# 챗
# 내
# 데이터
# 함부로
# 집단소송
# 오픈
# 리파
# 빅데이터
# 센터
# 구축
# 사업
# 로드맵
# 발표
# 임영웅
# 트로트
# 가수
# 브랜드
# 평판
# 빅데이터
# 위
# 차지
# 출발
# 서해안
# 시대
# 데이터
# 센터
# 구축
# 최적
# 전남
# 빚
# 연체
# 전
# 통화
# 기록
# 징후
# 빅데이터
# 분석
# 초
# 거대
# 시대
# 데이터
# 공유
# 기본
# 원칙
# 법
# 제화
# 필요
# 빅데이터
# 쇼
# 우리
# 이모저모
# 베트남
# 빅
# 테크
# 일군
# 하노이
# 게이츠
# 인터뷰
# 데이터
# 환경
# 스노우플레이크
# 관리
# 활
# 농협
# 중앙회
# 농업
# 빅데이터
# 플랫폼
# 구축
# 프로필
# 남우
# 창
# 국세청
# 빅데이터
# 센터
# 엔비디아
# 독식
# 토종
# 클라우드
# 빅
# 반도체
# 연합군
# 클라우드
# 방
# 바디
# 워시
# 브랜드
# 평판
# 빅데이터
# 분석
# 결과
# 위
# 강
# 중구
# 신임
# 심평원
# 약
# 빅데이터
# 관련
# 가이드라인
# 정비
# 국산
# 반도체
# 활용
# 전력
# 데이터
# 센터
# 구축
# 착수
# 빅데이터
# 암
# 정복
# 통계청
# 통계
# 데이터
# 국림
# 센터
# 신설
# 코인
# 빅데이터
# 비트코인
# 캐시
# 더
# 리움
# 클래식
# 트렌드
# 빅데이터
# 세상
# 이낙연
# 전
# 민주당
# 대표
# 귀국
# 한국
# 농수산
# 식품
# 유통
# 공사
# 민관
# 빅데이터
# 활용
# 농업
# 유통
# 디지털
# 전환
# 김해시
# 행안부
# 빅데이터
# 공모
# 사업
# 선정
# 국비
# 확보
# 빅데이터
# 신재생에너지
# 발
# 전량
# 예측
# 현대
# 에너지
# 솔루션
# 전력
# 중개
# 사업
# 심평원
# 빅데이터
# 개방
# 포털
# 전면
# 개편
# 페넬로페
# 기저귀
# 브랜드
# 평판
# 빅데이터
# 위
# 전북도
# 데이터
# 개방
# 수요
# 설문조사
# 달
# 진행
# 상명대학교
# 이씨
# 마이너
# 빅데이터
# 인공
# 지능
# 인재
# 양성
# 손
# 윤석열
# 대통령
# 수능
# 발언
# 핵심
# 사교육
# 척결
# 배종찬
# 정치
# 빅
# 데이
# 데이터
# 커머스
# 콕
# 배송비
# 전면
# 무료
# 광진구
# 빅데이터
# 분석
# 공모
# 시상식
# 개최
# 신세계
# 앤
# 빅데이터
# 개발자
# 컨퍼런스
# 데브
# 엑스
# 개최
# 청년
# 발언
# 의료
# 바이오
# 빅데이터
# 개방
# 앞
# 의료
# 기술
# 개발
# 빅데이터
# 쇼
# 이스트소프트
# 준비
# 휴먼
# 기술
# 호평
# 리츠
# 브랜드
# 평판
# 빅데이터
# 분석
# 결과
# 조달청
# 제
# 조달
# 빅데이터
# 활용
# 아이디어
# 공모전
# 바이오
# 전략
# 자산
# 빅데이터
# 구축
# 플로우
# 의료기기
# 상장
# 기업
# 브랜드
# 평판
# 빅데이터
# 분석
# 톱
# 심평원
# 빅데이터
# 개방
# 포털
# 전면
# 개편
# 플로우
# 의료기기
# 상장
# 기업
# 브랜드
# 평판
# 빅데이터
# 분석
# 톱
# 심평원
# 빅데이터
# 개방
# 포털
# 전면
# 개편
# 장성군
# 클라우드
# 데이터
# 센터
# 구축
# 환자
# 명
# 빅데이터
# 개방
# 대전
# 상의
# 특허
# 빅데이터
# 기반
# 미래
# 유망
# 기술
# 제시
# 옥천군
# 빅데이터
# 기반
# 관광
# 개발
# 마케팅
# 탄력
# 광주시
# 데이터
# 플랫폼
# 등
# 개
# 기업
# 업무
# 협약
# 김해시
# 행안부
# 빅데이터
# 공모
# 사업
# 선정
# 유플러스
# 데이터
# 커머스
# 콕
# 배송비
# 전면
# 무료
# 경기도
# 위기
# 징후
# 빅데이터
# 활용
# 복지
# 사각
# 지대
# 명
# 지원
# 심평원
# 빅데이터
# 접근성
# 국민
# 건강
# 증진
# 도모
# 옥천군
# 빅데이터
# 기반
# 관광
# 개발
# 마케팅
# 탄력
# 해운
# 상장
# 기업
# 브랜드
# 평판
# 빅데이터
# 분석
# 선두
# 평판
# 지수
# 상승
# 광주시
# 데이터
# 플랫폼
# 등
# 개
# 기업
# 업무
# 협약
# 김해시
# 행안부
# 빅데이터
# 공모
# 사업
# 선정
# 유플러스
# 데이터
# 커머스
# 콕
# 배송비
# 전면
# 무료
# 경기도
# 위기
# 징후
# 빅데이터
# 활용
# 복지
# 사각
# 지대
# 명
# 지원
# 한수정
# 종자
# 정보
# 빅데이터
# 기업
# 개방
# 바이오
# 산업
# 육성
# 선도
# 건설
# 빅데이터
# 스타트업
# 프리
# 투자
# 유치
# 포항시
# 빅데이터
# 기반
# 대기
# 환경
# 대응
# 시스템
# 구축
# 심평원
# 빅데이터
# 개방
# 포털
# 전면
# 개편
# 의료기기
# 상장
# 기업
# 브랜드
# 평판
# 빅데이터
# 분석
# 결과
# 위
# 플로우
# 위
# 경기도
# 위기
# 징후
# 빅데이터
# 활용
# 복지
# 사각
# 지대
# 명
# 지원
# 한수정
# 종자
# 정보
# 빅데이터
# 기업
# 개방
# 바이오
# 산업
# 육성
# 선도
# 건설
# 빅데이터
# 스타트업
# 프리
# 투자
# 유치
# 데이터
# 커머스
# 콕
# 배송비
# 전면
# 무료
# 포항시
# 빅데이터
# 기반
# 대기
# 환경
# 대응
# 시스템
# 구축
# 고흥군
# 순천대
# 스마트
# 혁신
# 밸리
# 빅데이터
# 센터
# 운영
# 위탁
# 금융
# 공공기관
# 브랜드
# 빅데이터
# 분석
# 결과
# 해수부
# 스마트
# 양식
# 빅데이터
# 센터
# 구축
# 사업
# 참여
# 지자체
# 모집
# 심평원
# 빅데이터
# 개방
# 포털
# 전면
# 개편
# 접근성
# 제
# 포항시
# 빅데이터
# 기반
# 대기
# 환경
# 대응
# 시스템
# 구축
# 고흥군
# 순천대
# 스마트
# 혁신
# 밸리
# 빅데이터
# 센터
# 운영
# 위탁
# 금융
# 공공기관
# 브랜드
# 빅데이터
# 분석
# 결과
# 해수부
# 스마트
# 양식
# 빅데이터
# 센터
# 구축
# 사업
# 참여
# 지자체
# 모집
# 데이터
# 센터
# 지방
# 분산
# 발
# 건설
# 빅데이터
# 스타트업
# 프리
# 투자
# 유치
# 경남
# 미래
# 교육
# 빅데이터
# 인공
# 지능
# 활용
# 수업
# 혁신
# 사례
# 눈길
# 기획
# 빅데이터
# 접목
# 렌탈
# 플랫폼
# 공기청정기
# 브랜드
# 평판
# 빅데이터
# 분석
# 결과
# 위
# 전자
# 위
# 삼성
# 전자
# 통운
# 디지털
# 유통
# 대전
# 참가
# 빅데이터
# 기반
# 물류
# 플랫폼
# 장성군
# 카카오
# 데이터
# 센터
# 투자
# 협약
# 체결
# 인터넷
# 전문
# 은행
# 브랜드
# 평판
# 빅데이터
# 분석
# 결과
# 위
# 케이
# 뱅크
# 위
# 카카
# 옥천군
# 빅데이터
# 컨설팅
# 공모
# 선정
# 경기도
# 빅데이터
# 활용
# 복지
# 사각
# 지대
# 명
# 발굴
# 지원
# 빅데이터
# 사회
# 기업
# 지원
# 신한카드
# 경기도
# 주식회사
# 협력
# 건강
# 기능
# 식품
# 상장
# 기업
# 브랜드
# 평판
# 빅데이터
# 분석
# 톱
# 심평원
# 빅데이터
# 개방
# 포털
# 전면
# 개편
# 진주
# 인공
# 지능
# 빅데이터
# 활용
# 생활
# 밀착
# 스마트
# 도시
# 로
# 대전
# 상의
# 특허
# 빅데이터
# 기반
# 미래
# 유망
# 기술
# 제시
# 대전
# 상의
# 특허
# 빅데이터
# 기반
# 미래
# 유망
# 기술
# 제시
# 전남
# 장성
# 규모
# 데이터
# 센터
# 샘
# 가구
# 상장
# 기업
# 브랜드
# 평판
# 빅데이터
# 분석
# 선두
# 평판
# 지수
# 하락
# 전남도
# 카카오
# 엔터프라이즈
# 등
# 장성
# 데이터
# 센터
# 구축
# 협약
# 빅데이터
# 전남
# 이슈
# 관광
# 광양
# 한국
# 노총
# 영암
# 아우토반
# 도로공사
# 스마트
# 건설
# 데이터
# 디지털
# 플랫폼
# 기술
# 세미나
# 개최
# 고창군
# 행안부
# 빅데이터
# 표준
# 분석
# 모델
# 정립
# 사업
# 공모
# 선정
# 심평원
# 빅데이터
# 개방
# 포털
# 개편
# 데이터
# 결합
# 온라인
# 서비스
# 엑스
# 로그
# 카카오
# 클라우드
# 데이터
# 관
# 복제
# 솔루션
# 등록
# 건설
# 빅데이터
# 플랫폼
# 산업
# 의역
# 운영
# 사
# 투자
# 유치
# 건설
# 빅데이터
# 플랫폼
# 산업
# 의역
# 운영
# 사
# 투자
# 유치
# 전남도
# 카카오
# 엔터프라이즈
# 등
# 데이터
# 센터
# 구축
# 협약
# 약국
# 건기
# 분
# 상담
# 알고리즘
# 빅데이터
# 더
# 장성군
# 규모
# 카카오
# 데이터
# 센터
# 유치
# 성공
# 정부
# 보유
# 환자
# 빅데이터
# 연구자
# 개방
# 빅데이터
# 쇼
# 챗
# 붐
# 타고
# 성황
# 현대
# 에너지
# 솔루션
# 전력
# 중개
# 사업
# 개시
# 태양광
# 발전소
# 빅데이터
# 활용
# 계명대
# 동산의료원
# 스마트
# 플랫폼
# 빅데이터
# 서비스
# 구축
# 착수
# 빅데이터
# 활용
# 저작권
# 침해
# 종합
# 대응
# 사업
# 설명
# 회
# 소상
# 공인
# 디지털
# 전환
# 촉진
# 빅데이터
# 플랫폼
# 구축
# 본격
# 소상
# 공인
# 디지털
# 전환
# 촉진
# 빅데이터
# 플랫폼
# 구축
# 본격
# 장성군
# 규모
# 데이터
# 센터
# 데이터
# 커머스
# 콕
# 배송비
# 전면
# 무료
# 핏
# 데이터
# 삼성
# 화재
# 애니
# 핏
# 플러스
# 새
# 광고
# 가구
# 상장
# 기업
# 브랜드
# 평판
# 빅데이터
# 분석
# 결과
# 위
# 샘
# 위
# 에이스침대
# 알
# 에스
# 한국
# 관광
# 데이터
# 랩
# 관광
# 수요
# 데이터
# 제공
# 스마트
# 양식
# 빅데이터
# 센터
# 구축
# 지자체
# 공모
# 국가
# 바이오
# 빅데이터
# 연구개발
# 전면
# 개방
# 경기도
# 빅데이터
# 복지
# 사각
# 지대
# 발굴
# 김해시
# 행안부
# 빅데이터
# 공모
# 사업
# 선정
# 국비
# 확보
# 데이터
# 커머스
# 플랫폼
# 콕
# 배송비
# 무료
# 스마트
# 양식
# 빅데이터
# 센터
# 구축
# 지자체
# 공모
# 투입
# 경기도
# 빅데이터
# 복지
# 사각
# 지대
# 발굴
# 김해시
# 행안부
# 빅데이터
# 공모
# 사업
# 선정
# 국비
# 확보
# 전남
# 장성군
# 규모
# 카카오
# 데이터
# 센터
# 챗
# 내
# 데이터
# 함부로
# 집단소송
# 오픈
# 리파
# 빅데이터
# 센터
# 구축
# 사업
# 로드맵
# 발표
# 임영웅
# 트로트
# 가수
# 브랜드
# 평판
# 빅데이터
# 위
# 차지
# 옥천군
# 충북도
# 내
# 유일
# 빅데이터
# 컨설팅
# 공모
# 선정
# 출발
# 서해안
# 시대
# 데이터
# 센터
# 구축
# 최적
# 전남
# 데이터
# 커머스
# 콕
# 배송비
# 무료
# 출발
# 서해안
# 시대
# 데이터
# 센터
# 구축
# 최적
# 전남
# 브랜드
# 평판
# 하이엔드
# 아파트
# 빅데이터
# 분석
# 결과
# 위
# 현대
# 건설
# 경기도
# 빅데이터
# 활용
# 복지
# 사각
# 지대
# 명
# 지원
# 빚
# 연체
# 전
# 통화
# 기록
# 징후
# 빅데이터
# 분석
# 초
# 거대
# 시대
# 데이터
# 공유
# 기본
# 원칙
# 법
# 제화
# 필요
# 빅데이터
# 쇼
# 우리
# 이모저모
# 소상
# 공인
# 빅데이터
# 플랫폼
# 구축
# 속도
# 자료
# 범위
# 규정
# 베트남
# 빅
# 테크
# 일군
# 하노이
# 게이츠
# 인터뷰
# 데이터
# 환경
# 스노우플레이크
# 관리
# 활
# 인터뷰
# 데이터
# 환경
# 스노우플레이크
# 관리
# 활
# 화장품
# 브랜드
# 평판
# 빅데이터
# 분석
# 결과
# 위
# 겔
# 위
# 닥터
# 유플러스
# 데이터
# 커머스
# 콕
# 배송비
# 무료
# 이용
# 가능
# 농협
# 중앙회
# 농업
# 빅데이터
# 플랫폼
# 구축
# 대전
# 상공회의소
# 특허
# 빅데이터
# 기반
# 산업
# 혁신
# 전략
# 유망
# 기술
# 세미나
# 건강
# 관리
# 장비
# 상장
# 기업
# 브랜드
# 평판
# 빅데이터
# 분석
# 결과
# 위
# 셀
# 바스
# 상명대
# 이씨
# 마이너
# 빅데이터
# 인재
# 해수부
# 스마트
# 양식
# 빅데이터
# 센터
# 구축
# 지자체
# 모집
# 장성군
# 규모
# 카카오
# 데이터
# 센터
# 하이엔드
# 아파트
# 브랜드
# 평판
# 빅데이터
# 분석
# 결과
# 위
# 현대
# 건설
# 디
# 에이치
# 해수부
# 스마트
# 양식
# 빅데이터
# 센터
# 구축
# 지자체
# 모집
# 장성군
# 규모
# 카카오
# 데이터
# 센터
# 하이엔드
# 아파트
# 브랜드
# 평판
# 빅데이터
# 분석
# 결과
# 위
# 현대
# 건설
# 디
# 에이치
# 데이터
# 커머스
# 콕
# 배송비
# 무료
# 이용
# 장성
# 클라우드
# 데이터
# 센터
# 구축
# 도로공사
# 스마트
# 건설
# 데이터
# 디지털
# 플랫폼
# 기술
# 세미나
# 개최
# 프로필
# 남우
# 창
# 국세청
# 빅데이터
# 센터
# 충북
# 옥천군
# 도내
# 유일
# 빅데이터
# 컨설팅
# 공모
# 선정
# 브랜드
# 평판
# 생물공학
# 상장
# 기업
# 빅데이터
# 분석
# 결과
# 위
# 바이오
# 엔비디아
# 독식
# 토종
# 클라우드
# 빅
# 반도체
# 연합군
# 클라우드
# 브랜드
# 평판
# 생물공학
# 상장
# 기업
# 빅데이터
# 분석
# 결과
# 위
# 바이오
# 엔비디아
# 독식
# 토종
# 클라우드
# 빅
# 반도체
# 연합군
# 클라우드
# 한국
# 도로공사
# 스마트
# 건설
# 데이터
# 및
# 디지털
# 플랫폼
# 기술
# 세미나
# 개최
# 서울시
# 올리브
# 네트웍
# 스
# 협력
# 서울
# 생활
# 물류
# 데이터
# 개방
# 방
# 바디
# 워시
# 브랜드
# 평판
# 빅데이터
# 분석
# 결과
# 위
# 브랜드
# 평판
# 대한민국
# 기초
# 자치
# 단체
# 빅데이터
# 분석
# 결과
# 위
# 데이터
# 커머스
# 콕
# 배송비
# 전면
# 무료
# 강
# 중구
# 신임
# 심평원
# 약
# 빅데이터
# 관련
# 가이드라인
# 정비
# 국가
# 통합
# 바이오
# 빅데이터
# 구축
# 사업
# 타
# 통과
# 임
# 데이터
# 등
# 통
# 국산
# 반도체
# 활용
# 전력
# 데이터
# 센터
# 구축
# 착수
# 카카오
# 엔터프라이즈
# 장성
# 남면
# 데이터
# 센터
# 구축
# 빅데이터
# 암
# 정복
# 통계청
# 통계
# 데이터
# 국림
# 센터
# 신설
# 코인
# 빅데이터
# 비트코인
# 캐시
# 더
# 리움
# 클래식
# 트렌드
# 빅데이터
# 세상
# 이낙연
# 전
# 민주당
# 대표
# 귀국
# 암
# 환자
# 빅데이터
# 개방
# 심의
# 후
# 제공
# 도로공사
# 스마트
# 건설
# 데이터
# 기술
# 세미나
# 개최
# 한국
# 농수산
# 식품
# 유통
# 공사
# 민관
# 빅데이터
# 활용
# 농업
# 유통
# 디지털
# 전환
# 빅데이터
# 투데이
# 리츠
# 브랜드
# 평판
# 랭킹
# 위
# 롯데
# 리츠
# 위
# 김해시
# 행안부
# 빅데이터
# 공모
# 사업
# 선정
# 국비
# 확보
# 생물공학
# 상장
# 기업
# 브랜드
# 평판
# 빅데이터
# 분석
# 결과
# 위
# 바이오
# 니아
# 위
# 리츠
# 브랜드
# 평판
# 빅데이터
# 분석
# 결과
# 위
# 롯데
# 리츠
# 위
# 리츠
# 위
# 제
# 유플러스
# 데이터
# 커머스
# 콕
# 배송비
# 전면
# 무료
# 신한카드
# 빅데이터
# 사회
# 기업
# 매출
# 견인
# 빅데이터
# 신재생에너지
# 발
# 전량
# 예측
# 현대
# 에너지
# 솔루션
# 전력
# 중개
# 사업
# 빅데이터
# 개발
# 포털
# 연구
# 분석
# 지원
# 강화
# 등
# 개편
# 심평원
# 빅데이터
# 개방
# 포털
# 전면
# 개편
# 한국
# 도로공사
# 스마트
# 건설
# 데이터
# 및
# 디지털
# 플랫폼
# 기술
# 세미나
# 개최
# 페넬로페
# 기저귀
# 브랜드
# 평판
# 빅데이터
# 위
# 소상
# 공인
# 빅데이터
# 플랫폼
# 구축
# 순항
# 국무회의
# 관련
# 법안
# 의결
# 전북도
# 데이터
# 개방
# 수요
# 설문조사
# 달
# 진행
# 전북도
# 데이터
# 개방
# 수요
# 설문조사
# 달
# 진행
# 브랜드
# 평판
# 가정
# 용품
# 상장
# 기업
# 빅데이터
# 분석
# 결과
# 위
# 코웨이
# 데이터
# 커머스
# 콕
# 모든
# 상품
# 배송비
# 전면
# 무료
# 상명대학교
# 이씨
# 마이너
# 빅데이터
# 인공
# 지능
# 인재
# 양성
# 손
# 윤석열
# 대통령
# 수능
# 발언
# 핵심
# 사교육
# 척결
# 배종찬
# 정치
# 빅
# 데이
# 암
# 환자
# 데이터
# 연구자
# 개방
# 서울
# 사이버대
# 빅데이터
# 센터
# 빅데이터
# 정보보호
# 학과
# 인공
# 지능
# 팩토리
# 김태영
# 건강
# 기능
# 식품
# 상장
# 기업
# 브랜드
# 평판
# 빅데이터
# 분석
# 결과
# 위
# 위
# 장성군
# 남면
# 규모
# 데이터
# 센터
# 유치
# 심층
# 빅데이터
# 오세훈
# 호
# 이태원
# 참사
# 당시
# 검색
# 위
# 서울
# 뉴
# 심층
# 빅데이터
# 오세훈
# 호
# 이태원
# 참사
# 당시
# 검색
# 위
# 서울
# 뉴
# 새만금
# 청
# 공공
# 빅데이터
# 활용
# 공모전
# 개최
# 아이디어
# 정책
# 과제
# 발굴
# 스타
# 브랜드
# 평판
# 빅데이터
# 분석
# 결과
# 위
# 방탄소년단
# 위
# 임영웅
# 위
# 강
# 장성
# 규모
# 데이터
# 센터
# 데이터
# 커머스
# 콕
# 상품
# 배송비
# 전면
# 무료
# 빅데이터
# 시대
# 위기
# 도민
# 명
# 안정
# 지원
# 우리동네
# 화재
# 안전
# 지수
# 소방청
# 빅데이터
# 분석
# 사업
# 방탄소년단
# 가수
# 브랜드
# 평판
# 빅데이터
# 위
# 차지
# 중
# 기부
# 소상
# 공인
# 빅데이터
# 플랫폼
# 구축
# 박차
# 회계감사
# 빅데이터
# 활용
# 감사
# 사각
# 지대
# 수
# 것
# 회계감사
# 빅데이터
# 활용
# 감사
# 사각
# 지대
# 수
# 것
# 규모
# 암
# 환자
# 빅데이터
# 학계
# 산업
# 본격
# 개방
# 달
# 의료
# 빅데이터
# 연구자
# 산업
# 천군
# 마
# 전남도
# 카카오
# 등
# 장성
# 데이터
# 센터
# 구축
# 협약
# 장성군
# 규모
# 데이터
# 센터
# 우리동네
# 화재
# 위험
# 예측
# 빅데이터
# 분석
# 사업
# 추진
# 보증
# 보험
# 브랜드
# 평판
# 빅데이터
# 분석
# 결과
# 위
# 서울
# 보증
# 보험
# 위
# 신용
# 보
# 해수부
# 스마트
# 양식
# 빅데이터
# 센터
# 구축
# 지자체
# 공모
# 빅데이터
# 쇼
# 연구원
# 생
# 유즈
# 케이스
# 구축
# 가장
# 중요
# 데이터스트림즈
# 의료
# 올해
# 매출
# 베트남
# 등
# 해외
# 진출
# 해수부
# 스마트
# 양식
# 빅데이터
# 센터
# 구축
# 지자체
# 공모
# 카카오
# 데이터
# 센터
# 전남
# 장성
# 구축
# 빅데이터
# 쇼
# 연구원
# 생
# 유즈
# 케이스
# 구축
# 가장
# 중요
# 데이터스트림즈
# 의료
# 올해
# 매출
# 베트남
# 등
# 해외
# 진출
# 브랜드
# 평판
# 종이
# 목재
# 상장
# 기업
# 빅데이터
# 분석
# 결과
# 위
# 영풍
# 제
# 엑스
# 로그
# 카카오
# 클라우드
# 데이터
# 관
# 복제
# 솔루션
# 등록
# 환자
# 명
# 빅데이터
# 민간
# 연구자
# 개방
# 빅데이터
# 투데이
# 아기
# 화장품
# 브랜드
# 평판
# 랭킹
# 위
# 몽디
# 에스
# 전남
# 장성
# 카카오
# 첨단
# 데이터
# 센터
# 한국
# 도로공사
# 스마트
# 건설
# 데이터
# 및
# 디지털
# 플랫폼
# 기술
# 세미나
# 개최
# 농협
# 올해
# 제
# 차
# 디지털
# 혁신
# 위
# 개최
# 빅데이터
# 플랫폼
# 구축
# 장성군
# 규모
# 카카오
# 데이터
# 센터
# 빅데이터
# 쇼
# 전시회
# 인공
# 지능
# 산업대
# 수상
# 기업
# 가정
# 용품
# 상장
# 기업
# 브랜드
# 평판
# 빅데이터
# 분석
# 결과
# 위
# 코웨이
# 위
# 농업
# 빅데이터
# 플랫폼
# 구축
# 게시판
# 통계청
# 아태
# 개도국
# 공무원
# 빅데이터
# 역량
# 강화
# 연수
# 비투
# 빅데이터
# 쇼
# 학습
# 데이터
# 통합
# 플랫폼
# 플로
# 첫
# 고흥군
# 순천대
# 빅데이터
# 기반
# 스마트
# 농업
# 기술
# 지원
# 협력
# 국가
# 바이오
# 빅데이터
# 명분
# 연구개발
# 개방
# 보건복지부
# 환자
# 빅데이터
# 개방
# 보건복지부
# 환자
# 빅데이터
# 개방
# 빅데이터
# 전북
# 이슈
# 교육
# 새만금
# 관광
# 빅데이터
# 쇼
# 펀진
# 국방
# 기술
# 선두
# 주자
# 것
# 조달청
# 조달
# 빅데이터
# 활용
# 아이디어
# 공모
# 리파
# 빅데이터
# 센터
# 구축
# 사업
# 로드맵
# 발표
# 데이터
# 기반
# 정책
# 수립
# 구미시
# 빅데이터
# 분석
# 사업
# 시행
# 데이터
# 기반
# 디지털
# 전환
# 부산
# 데이터
# 위
# 해수부
# 스마트
# 양식
# 빅데이터
# 센터
# 구축
# 사업
# 참여
# 지자체
# 모집
# 한국
# 도로공사
# 스마트
# 건설
# 데이터
# 및
# 디지털
# 플랫폼
# 기술
# 세미나
# 개최
# 전문
# 대학
# 브랜드
# 평판
# 빅데이터
# 분석
# 결과
# 코인
# 빅데이터
# 빅
# 암호
# 화폐
# 비트코인
# 더
# 리움
# 트렌드
# 전남도
# 장성군
# 카카오
# 데이터
# 센터
# 구축
# 초
# 거대
# 시대
# 데이터
# 개방
# 공유
# 필요
# 유럽
# 규제
# 양해
# 유플러스
# 데이터
# 커머스
# 콕
# 배송비
# 무료
# 명
# 유전자
# 등
# 바이오
# 빅데이터
# 달
# 말
# 민간
# 개방
# 통계청
# 개도국
# 공무원
# 빅데이터
# 연수
# 실시
# 빅
# 병원
# 환자
# 해법
# 모색
# 절실
# 장성군
# 규모
# 카카오
# 데이터
# 센터
# 유치
# 농협
# 중앙회
# 농업
# 빅데이터
# 플랫폼
# 전환
# 아기
# 화장품
# 브랜드
# 평판
# 빅데이터
# 분석
# 결과
# 위
# 몽디
# 에스
# 위
# 아토
# 농협
# 중앙회
# 농업
# 빅데이터
# 플랫폼
# 전환
# 장성군
# 규모
# 데이터
# 센터
# 아기
# 화장품
# 브랜드
# 평판
# 빅데이터
# 분석
# 결과
# 위
# 몽디
# 에스
# 위
# 아토
# 해수부
# 스마트
# 양식
# 빅데이터
# 센터
# 구축
# 사업
# 참여
# 지자체
# 모집
# 부산시
# 신청
# 김영식
# 회계사
# 회장
# 빅데이터
# 대형
# 회계법인
# 유물
# 신한카드
# 데이터
# 활용
# 경영
# 사회
# 기업
# 마케팅
# 지원
# 바이오
# 데이터
# 은행
# 구축
# 국가
# 전략
# 자산
# 한국
# 바이오
# 빅데이터
# 구축
# 암
# 희귀
# 질병
# 정복
# 상명대
# 빅데이터
# 전문
# 기업
# 이씨
# 마이너
# 산학
# 협력
# 협약
# 체결
# 카카오
# 엔터프라이즈
# 전남
# 장성
# 데이터
# 센터
# 구축
# 카카오
# 엔터프라이즈
# 전남
# 장성
# 데이터
# 센터
# 구축
# 전남
# 장성
# 규모
# 데이터
# 센터
# 골든플래닛
# 구글
# 클라우드
# 데이터
# 분석
# 전문
# 기업
# 인증
# 획득
# 비투
# 인공
# 지능
# 빅데이터
# 쇼
# 플로
# 공개
# 정부
# 바이오
# 빅데이터
# 공개
# 디지털
# 헬
# 스케
# 활용
# 도로공사
# 스마트
# 건설
# 데이터
# 디지털
# 플랫폼
# 기술
# 세미나
# 개최
# 장성군
# 카카오
# 엔터프라이즈
# 데이터
# 센터
# 설립
# 투자
# 협약
# 종이
# 목재
# 상장
# 기업
# 브랜드
# 평판
# 빅데이터
# 분석
# 결과
# 위
# 영풍
# 제지
# 위
# 깨
# 환자
# 빅데이터
# 개방
# 더
# 아이엠
# 설립
# 빅데이터
# 분석
# 예측
# 국내
# 선두
# 기업
# 김
# 장성
# 규모
# 카카오
# 데이터
# 센터
# 환자
# 빅데이터
# 개방
# 더
# 아이엠
# 설립
# 빅데이터
# 분석
# 예측
# 국내
# 선두
# 기업
# 김
# 글로벌
# 빅
# 테크
# 겨냥
# 데이터
# 법
# 합의
# 건설
# 빅데이터
# 스타트업
# 프리
# 투자
# 유치
# 리코
# 젠
# 헬
# 스케
# 빅데이터
# 린지
# 성황리
# 개최
# 국민
# 건강
# 기여
# 비투
# 인공
# 지능
# 빅데이터
# 쇼
# 플로
# 첫
# 공개
# 빅데이터
# 쇼
# 딥
# 브레인
# 휴먼
# 생
# 기술
# 심평원
# 의료
# 빅데이터
# 포털
# 이용
# 편의
# 증대
# 옥천군
# 빅데이터
# 컨설팅
# 공모
# 선정
# 옥천군
# 빅데이터
# 컨설팅
# 공모
# 선정
# 서울
# 사이버대
# 빅데이터
# 센터
# 빅데이터
# 정보보호
# 학과
# 김태영
# 인공
# 지능
# 팩토
# 전남도
# 카카오
# 등
# 장성
# 데이터
# 센터
# 구축
# 협약
# 경기도
# 데이터
# 분석
# 도정
# 활용
# 올해
# 고용
# 교통
# 주거
# 정비
# 상명대
# 이씨
# 마이너
# 빅데이터
# 인재
# 양성
# 손
# 브랜드
# 평판
# 금융
# 공공기관
# 빅데이터
# 분석
# 결과
# 위
# 서민
# 금융
# 진
# 데이터
# 커머스
# 콕
# 배송비
# 무료
# 이용
# 빅데이터
# 쇼
# 임
# 클라우드
# 휴먼
# 결합
# 메타
# 버스
# 완성
# 것
# 구미시
# 빅데이터
# 분석
# 통해
# 정책
# 방향
# 시한
# 장성군
# 규모
# 카카오
# 데이터
# 센터
# 장성군
# 규모
# 카카오
# 데이터
# 센터
# 엑스
# 로그
# 카카오
# 아이클라우드
# 데이터
# 관
# 및
# 복제
# 솔루션
# 등록
# 김한규
# 의원
# 익명
# 정보
# 활용
# 통해
# 빅데이터
# 산업
# 활성화
# 토대
# 구축
# 경기도
# 데이터
# 분석
# 도정
# 활용
# 보건
# 산업
# 진흥
# 리코
# 젠
# 헬
# 스케
# 빅데이터
# 린지
# 암
# 환자
# 빅데이터
# 개방
# 진단
# 치료
# 기술
# 연구개발
# 활용
# 국가
# 바이오
# 빅데이터
# 시범
# 사업
# 데이터
# 전면
# 개방
# 명분
# 수면
# 습관
# 청력
# 수준
# 공개
# 달
# 말
# 공개
# 명
# 바이오
# 빅
# 데이
# 누구
# 데이터
# 정보
# 문화
# 유공
# 과
# 정통부
# 장관
# 표창
# 수상
# 비영리단체
# 전남도
# 카카오
# 등
# 장성
# 데이터
# 센터
# 구축
# 협약
# 정부
# 명분
# 바이오
# 빅데이터
# 민간
# 개방
# 서울시
# 통운
# 기반
# 서울
# 생활
# 물류
# 데이터
# 개방
# 고창군
# 빅데이터
# 표준
# 분석
# 모델
# 정립
# 사업
# 공모
# 선정
# 엑스
# 로그
# 카카오
# 클라우드
# 데이터
# 관
# 복제
# 솔루션
# 등록
# 데이터
# 커머스
# 콕
# 배송비
# 전면
# 무료
# 옥천군
# 도내
# 유일
# 빅데이터
# 컨설팅
# 공모
# 선정
# 구미시
# 빅데이터
# 분석
# 통해
# 정책
# 방향
# 제시
# 젠
# 데이터
# 경쟁력
# 배터리
# 사업
# 확장
# 걸음
# 알
# 에스
# 기술
# 활용
# 한국
# 관광
# 데이터
# 랩
# 서비스
# 제공
# 고흥군
# 순천대
# 스마트
# 혁신
# 밸리
# 빅데이터
# 센터
# 운영
# 위탁
# 고흥군
# 순천대
# 스마트
# 혁신
# 밸리
# 빅데이터
# 센터
# 운영
# 위탁
# 빅파마
# 발
# 국내
# 코로나
# 치료
# 제
# 개발
# 사
# 고심
# 경기도
# 신규
# 데이터
# 분석
# 사업
# 착수
# 보고
# 회
# 개최
# 은평구
# 도서관
# 직원
# 역량
# 강화
# 교육
# 빅데이터
# 플랫폼
# 구축
# 및
# 활용
# 바디
# 워시
# 브랜드
# 평판
# 빅데이터
# 분석
# 결과
# 위
# 방
# 위
# 해피
# 바스
# 위
# 경기도
# 위기
# 징후
# 빅데이터
# 활용
# 복지
# 사각
# 지대
# 명
# 자체
# 발굴
# 지원
# 해수부
# 스마트
# 양식
# 빅데이터
# 센터
# 구축
# 투입
# 공공
# 조달
# 데이터
# 활용
# 국민
# 아이디어
# 장성군
# 카카오
# 데이터
# 센터
# 구축
# 규모
# 강
# 중구
# 심평원
# 의료
# 빅데이터
# 개방
# 가닥
# 모든
# 비급
# 진료
# 급여
# 강
# 중구
# 심평원
# 의료
# 빅데이터
# 개방
# 가닥
# 모든
# 비급
# 진료
# 급여
# 지역
# 서울
# 택배
# 데이터
# 공개
# 빅데이터
# 쇼
# 아크릴
# 옵스
# 나단
# 기업
# 관계자
# 관심
# 집중
# 경기도
# 데이터
# 분석
# 활용
# 고용
# 교통
# 생활
# 정책
# 수립
# 추진
# 부산
# 데이터
# 위
# 개막
# 벡스코
# 컨벤션
# 홀
# 광진구
# 빅데이터
# 분석
# 공모전
# 대상
# 불법
# 정차
# 대응
# 장성군
# 규모
# 카카오
# 데이터
# 센터
# 복지부
# 환자
# 빅데이터
# 개방
# 한국
# 도로공사
# 스마트
# 건설
# 데이터
# 및
# 디지털
# 플랫폼
# 기술
# 세미나
# 개최
# 빅데이터
# 투데이
# 정기예금
# 브랜드
# 평판
# 랭킹
# 위
# 우리은행
# 위
# 빅데이터
# 투데이
# 정기예금
# 브랜드
# 평판
# 랭킹
# 위
# 우리은행
# 위
# 전남도
# 카카오
# 등
# 장성
# 데이터
# 센터
# 구축
# 협약
# 조달청
# 조달
# 빅데이터
# 활용
# 아이디어
# 기획
# 공모전
# 상명대
# 빅데이터
# 전문
# 기업
# 이씨
# 마이너
# 산학
# 협력
# 협약
# 체결
# 하이닉스
# 데이터
# 센터
# 향
# 메모리
# 기술
# 공개
# 국립
# 공주대
# 기상
# 기후
# 데이터
# 융합
# 분석
# 특성
# 대학원
# 선정
# 스마트
# 양식
# 빅데이터
# 센터
# 구축
# 지자체
# 공모
# 건설
# 회사
# 브랜드
# 평판
# 빅데이터
# 분석
# 결과
# 경기도
# 위기
# 징후
# 빅데이터
# 활용
# 복지
# 사각
# 지대
# 명
# 자체
# 발굴
# 금융
# 공공기관
# 브랜드
# 평판
# 빅데이터
# 분석
# 결과
# 위
# 서민
# 금융
# 진흥
# 위
# 장성
# 데이터
# 센터
# 경기도
# 위기
# 징후
# 빅데이터
# 활용
# 복지
# 사각
# 지대
# 명
# 자체
# 발굴
# 금융
# 공공기관
# 브랜드
# 평판
# 빅데이터
# 분석
# 결과
# 위
# 서민
# 금융
# 진흥
# 위
# 샘
# 인테리어
# 상장
# 기업
# 브랜드
# 평판
# 빅데이터
# 분석
# 톱
# 섬유
# 의류
# 상장
# 기업
# 브랜드
# 평판
# 빅데이터
# 분석
# 위
# 경기도
# 데이터
# 분석
# 도정
# 활용
# 소상
# 공인
# 빅데이터
# 플랫폼
# 구축
# 법적
# 근거
# 마련
# 상공
# 법
# 시행
# 령
# 개정
# 고창군
# 빅데이터
# 표준
# 분석
# 공모
# 선정
# 김한규
# 의원
# 익명
# 처리
# 데이터
# 산업
# 활성화
# 추진
# 브랜드
# 평판
# 대한민국
# 광역
# 자치
# 단체
# 빅데이터
# 분석
# 결과
# 위
# 김한규
# 의원
# 익명
# 처리
# 데이터
# 산업
# 활성화
# 추진
# 브랜드
# 평판
# 대한민국
# 광역
# 자치
# 단체
# 빅데이터
# 분석
# 결과
# 위
# 광주
# 시내버스
# 빅데이터
# 기반
# 안전
# 모니터링
# 시스템
# 구축
# 정기예금
# 브랜드
# 평판
# 빅데이터
# 분석
# 결과
# 위
# 우리은행
# 위
# 저축은행
# 가명
# 정보
# 사용
# 금융
# 데이터
# 라이브러리
# 도입
# 탁
# 빅데이터
# 가수
# 브랜드
# 위
# 박서진
# 이찬원
# 양준
# 일
# 박지현
# 진
# 해양수산부
# 스마트
# 양식
# 빅데이터
# 센터
# 구축
# 지자체
# 공모
# 전남도
# 장성군
# 규모
# 첨단
# 데이터
# 센터
# 장성군
# 규모
# 데이터
# 센터
# 설립
# 투자
# 협약
# 체결
# 디
# 에스티
# 인터
# 날
# 데이터
# 로
# 성장
# 박차
# 데이터
# 커머스
# 콕
# 배송비
# 무료
# 이용
# 사이버
# 대학교
# 브랜드
# 평판
# 빅데이터
# 분석
# 결과
# 위
# 서울
# 사이버
# 대학교
# 위
# 조달
# 데이터
# 활용
# 국민
# 아이디어
# 고창군
# 빅데이터
# 표준
# 분석
# 모델
# 정립
# 사업
# 공모
# 선정
# 강원
# 정보
# 문화
# 산업
# 진흥
# 데이터
# 의료
# 건강
# 생태계
# 조성
# 사업
# 설명
# 회
# 개최
# 빅
# 테크
# 해고
# 비용
# 절감
# 실리콘밸리
# 실률
# 바이오
# 빅데이터
# 승부
# 패
# 장기
# 지원
# 책
# 하이닉스
# 협력
# 강화
# 데이터
# 센터
# 메모리
# 사업
# 속도
# 강태오
# 빅데이터
# 배우
# 브랜드
# 순위
# 위
# 이세영
# 이준혁
# 김태리
# 마동
# 고흥
# 스마트
# 혁신
# 밸리
# 빅데이터
# 센터
# 운영
# 위
# 수탁
# 협약
# 체결
# 카카오
# 엔터프라이즈
# 전남
# 장성
# 데이터
# 센터
# 구축
# 농협
# 범
# 농협
# 디지털
# 혁신
# 위
# 개최
# 데이터
# 기반
# 농업
# 환경
# 조성
# 논의
# 바이오
# 빅데이터
# 시범
# 사업
# 데이터
# 전면
# 개방
# 금융시장
# 진입
# 기준
# 충돌
# 금융
# 빅
# 테크
# 바이오
# 빅데이터
# 전면
# 개방
# 신약
# 개발
# 탄력
# 한국
# 보건
# 산업
# 진흥
# 리코
# 젠
# 헬
# 스케
# 빅데이터
# 쇼케이스
# 데이터
# 분석
# 구미시
# 빅데이터
# 기반
# 맞춤
# 정책
# 추진
# 분석
# 사업
# 브랜드
# 평판
# 섬유
# 의류
# 상장
# 기업
# 빅데이터
# 분석
# 결과
# 위
# 조달청
# 조달
# 빅데이터
# 활용
# 아이디어
# 기획
# 공모전
# 개최
# 생
# 성형
# 빅
# 테크
# 생
# 성형
# 빅
# 테크
# 구글
# 빅
# 쿼리
# 게임
# 데이터
# 분석
# 인사이트
# 도출
# 부산
# 데이터
# 위
# 개최
# 빅데이터
# 쇼
# 캐리어
# 냉장
# 무인
# 기술
# 새
# 제시
# 명
# 바이오
# 빅데이터
# 개방
# 의료
# 민영화
# 우려
# 고창군
# 빅데이터
# 표준
# 분석
# 모델
# 정립
# 사업
# 공모
# 선정
# 조달청
# 조달
# 데이터
# 활용
# 아이디어
# 공모전
# 경기도
# 빅데이터
# 활용
# 복지사
# 지대
# 명
# 기획
# 발굴
# 지원
# 울산
# 시내버스
# 노선
# 빅데이터
# 활용
# 하반기
# 전면
# 개편
# 중부
# 최대
# 규모
# 충주
# 데이터
# 센터
# 삽
# 심평원
# 빅데이터
# 개방
# 포털
# 전면
# 개편
# 박수영
# 민경욱
# 머
# 저리
# 저격
# 연
# 데이터
# 선관위
# 제공
# 힐스테이트
# 아파트
# 브랜드
# 평판
# 빅데이터
# 위
# 울산
# 시내버스
# 노선
# 빅데이터
# 활용
# 전면
# 개편
# 미소
# 정보기술
# 스마트
# 통해
# 의료
# 기관
# 데이터
# 자동화
# 구미시
# 빅데이터
# 분석
# 정책
# 방향
# 제시
# 빅
# 테크
# 감독
# 기관
# 서울
# 개인정보
# 위
# 규제
# 물꼬
# 인공
# 지능
# 기업
# 광주
# 행
# 계속
# 광주
# 광역시
# 데이터
# 플랫폼
# 콘텐츠
# 등
# 장성군
# 규모
# 데이터
# 센터
# 구축
# 포토
# 유플러스
# 데이터
# 커머스
# 콕
# 배송비
# 무료
# 이용
# 장성군
# 규모
# 데이터
# 센터
# 구축
# 포토
# 유플러스
# 데이터
# 커머스
# 콕
# 배송비
# 무료
# 이용
# 애플
# 비자
# 현대
# 카드
# 빅
# 손
# 남구
# 공인
# 중개사
# 협
# 빅데이터
# 활용
# 교육
# 트로트
# 가수
# 브랜드
# 평판
# 빅데이터
# 분석
# 결과
# 위
# 임영웅
# 위
# 이찬원
# 위
# 농협
# 중앙회
# 디지털
# 혁신
# 위원회
# 올인원
# 빅데이터
# 플랫폼
# 구축
# 침대
# 브랜드
# 평판
# 빅데이터
# 분석
# 결과
# 위
# 시몬
# 스
# 위
# 이케아
# 위
# 샘
# 음원
# 거래
# 빅데이터
# 아이템
# 경기
# 불황
# 스타트업
# 빅데이터
# 쇼
# 핵심
# 데이터
# 첨단
# 기술
# 대표
# 기업
# 진단
# 전
# 사망
# 환자
# 빅데이터
# 린다
# 진단
# 전
# 사망
# 환자
# 빅데이터
# 린다
# 골든플래닛
# 구글
# 클라우드
# 데이터
# 분석
# 전문
# 기업
# 인증
# 경기도
# 데이터
# 분석
# 도정
# 활용
# 올해
# 고용
# 교통
# 주거
# 정비
# 분야
# 분석
# 쿠션
# 브랜드
# 평판
# 빅데이터
# 분석
# 결과
# 위
# 입생로랑
# 위
# 디올
# 위
# 정샘
# 비만
# 클리
# 닉
# 경희
# 디지털
# 헬스
# 센터
# 지방
# 흡입
# 빅데이터
# 기반
# 연구
# 상공
# 법
# 시행
# 령
# 개정안
# 국무회의
# 의결
# 빅데이터
# 플랫폼
# 구축
# 본격
# 대한민국
# 광역
# 자치
# 단체
# 브랜드
# 평판
# 빅데이터
# 분석
# 결과
# 위
# 서울시
# 위
# 서울
# 데이터
# 광장
# 데이터
# 활용
# 경진
# 대회
# 시상식
# 개최
# 금융위
# 금융
# 데이터
# 라이브러리
# 혁신
# 금융
# 서비스
# 지정
# 경기도
# 빅데이터
# 활용
# 위기
# 도민
# 하루
# 명
# 인
# 위기
# 가구

# %% [markdown]
# ### 정제(Cleaning)와 정규화(Normalization)
# - 정제 : 추출된 코퍼스로부터 결측값 및 필요없는 데이터를 제거
# - 정규화 : 같은 의미나 중복된 단어들을 통합
# - 정제 작업의 경우 한 번만 수행하는 것이 아니라 토큰화 작업 후에 남아있는 데이터들을 제거하기위해 반복수행할 수 있음

# %% [markdown]
# #### 불필요한 단어의 제거
# - 불필요한 단어는 아무 의미가 없는 글자나 단어, 혹은 분석 목적과 맞지 않는 단어를 의미
# - 또한, 단어의 등장 빈도가 적다면 자연어 처리에 특별하게 도움되지 않기 때문에 제거하는 것이 좋음
# - 단어의 길이가 짧은 단어도 의미가 없을 수 있음. 예를 들어, 차, 군, 인 등 의미가 중복되거나 단어 자체만으로는 의미가 모호한 단어들은 제거할 필요가 있음

# %%
# 네이버 뉴스 검색 결과에서 한 글자의 단어 제거
result = []
for l in titleNounsList:
    if len(l) > 1 :
        result.append(l)

print(result)
# Out:
# ['용인시', '각종', '데이터', '빅데이터', '플랫폼', '창원시', '빅데이터', '공모전', '개최', '접수', '취업', '걱정', '명품', '학교', '선일', '빅데이터', '고등학교', '포항시', '빅데이터', '기반', '대기', '환경', '개선', '교통', '약자', '장애인', '동권', '향상', '도보', '내비게이션', '빅데이터', '구축', '포항시', '빅데이터', '기반', '대기', '환경', '대응', '시스템', '구축', '예능', '프로그램', '빅데이터', '분석', '결과', '퀴즈', '블럭', '런닝맨', '엔비디아', '기업', '홍키', '바이오', '빅데이터', '구축', '사업', '예비', '타당성', '조사', '통과', '창원시', '빅데이터', '공모전', '모집', '신세계', '빅데이터', '기술', '그룹', '시너지', '엔비디아', '기업', '홍키', '바이오', '빅데이터', '구축', '사업', '통과', '바이오', '빅데이터', '구축', '사업', '예비', '타당성', '조사', '통과', '관광지', '옥천', '빅데이터', '진단', '협력', '랜섬', '웨어', '해킹', '피해', '안내면', '데이터', '공개', '황의조', '여론', '충격', '사생활', '영상', '데이터', '바이오', '빅데이터', '구축', '단계', '추진', '게시판', '심평원', '빅데이터', '개방', '포털', '전면', '개편', '상명대', '빅데이터', '전문', '기업', '이씨', '마이너', '산학', '협력', '협약', '스케', '자궁경부암', '영상', '진단', '플랫폼', '공개', '데이터', '민주화', '오픈소스', '코드', '가야', '데이터', '커머스', '배송비', '전면', '무료', '창원', '특례시', '창원', '빅데이터', '공모전', '에어컨', '브랜드', '평판', '빅데이터', '분석', '결과', '삼성', '전자', '전자', '해수부', '스마트', '양식', '빅데이터', '센터', '구축', '지자체', '공모', '빅데이터', '기반', '저작권', '침해', '종합', '대응', '시스템', '구축', '사업', '추진', '건보', '빅데이터', '기반', '척수', '손상', '합병증', '현황', '보고서', '발표', '하이엔드', '아파트', '브랜드', '평판', '빅데이터', '분석', '결과', '예능', '방송인', '브랜드', '평판', '빅데이터', '분석', '결과', '유재석', '탁재훈', '데이터', '플랫폼', '업계', '확산', '크로스', '플랫폼', '지원', '물살', '서울', '사이버대', '빅데이터', '센터', '빅데이터', '정보보호', '학과', '인공', '지능', '팩토리', '김태', '김해시', '행안부', '빅데이터', '분석', '모델', '공모', '사업', '선정', '정부', '공언', '공공', '의료', '데이터', '개방', '개인', '정보보호', '대전', '상의', '특허', '빅데이터', '기반', '미래', '유망', '기술', '세미나', '개최', '브랜드', '평판', '간편', '결제', '빅데이터', '분석', '결과', '네이버', '페이', '대전', '상의', '특허', '빅데이터', '기반', '미래', '유망', '기술', '제시', '조달청', '내달', '조달', '빅데이터', '활용', '아이디어', '공모', '서울시', '택배', '송장', '기반', '생활', '물류', '데이터', '공개', '의료', '바이오', '빅데이터', '장성', '클라우드', '데이터', '센터', '유치', '가동', '데이터', '수집', '권리', '개인정보', '보호', '균형', '신세계', '신세계', '그룹', '빅데이터', '개발자', '컨퍼런스', '광진구', '빅데이터', '분석', '공모', '시상식', '개최', '청년', '발언', '의료', '바이오', '빅데이터', '개방', '의료', '기술', '개발', '빅데이터', '이스트소프트', '준비', '휴먼', '기술', '호평', '리츠', '브랜드', '평판', '빅데이터', '분석', '결과', '바이오', '전략', '자산', '빅데이터', '구축', '장성군', '클라우드', '데이터', '센터', '구축', '광주시', '데이터', '플랫폼', '기업', '업무', '협약', '경기도', '위기', '징후', '빅데이터', '활용', '복지', '사각', '지대', '지원', '한수정', '종자', '정보', '빅데이터', '기업', '개방', '바이오', '산업', '육성', '선도', '건설', '빅데이터', '스타트업', '프리', '투자', '유치', '고흥군', '순천대', '스마트', '혁신', '밸리', '빅데이터', '센터', '운영', '위탁', '금융', '공공기관', '브랜드', '빅데이터', '분석', '결과', '경남', '미래', '교육', '빅데이터', '인공', '지능', '활용', '수업', '혁신', '사례', '눈길', '기획', '빅데이터', '접목', '렌탈', '플랫폼', '통운', '디지털', '유통', '대전', '참가', '빅데이터', '기반', '물류', '플랫폼', '빅데이터', '사회', '기업', '지원', '신한카드', '경기도', '주식회사', '협력', '건강', '기능', '식품', '상장', '기업', '브랜드', '평판', '빅데이터', '분석', '진주', '인공', '지능', '빅데이터', '활용', '생활', '밀착', '스마트', '도시', '가구', '상장', '기업', '브랜드', '평판', '빅데이터', '분석', '선두', '평판', '지수', '하락', '빅데이터', '전남', '이슈', '관광', '광양', '한국', '노총', '영암', '아우토반', '도로공사', '스마트', '건설', '데이터', '디지털', '플랫폼', '기술', '세미나', '개최', '고창군', '행안부', '빅데이터', '표준', '분석', '모델', '정립', '사업', '공모', '선정', '엑스', '로그', '카카오', '클라우드', '데이터', '복제', '솔루션', '등록', '약국', '건기', '상담', '알고리즘', '빅데이터', '빅데이터', '타고', '성황', '현대', '에너지', '솔루션', '전력', '중개', '사업', '개시', '태양광', '발전소', '빅데이터', '활용', '계명대', '동산의료원', '스마트', '플랫폼', '빅데이터', '서비스', '구축', '착수', '소상', '공인', '디지털', '전환', '촉진', '빅데이터', '플랫폼', '구축', '본격', '데이터', '삼성', '화재', '애니', '플러스', '광고', '에스', '한국', '관광', '데이터', '관광', '수요', '데이터', '제공', '국가', '바이오', '빅데이터', '연구개발', '전면', '개방', '데이터', '함부로', '집단소송', '오픈', '리파', '빅데이터', '센터', '구축', '사업', '로드맵', '발표', '임영웅', '트로트', '가수', '브랜드', '평판', '빅데이터', '차지', '출발', '서해안', '시대', '데이터', '센터', '구축', '최적', '전남', '연체', '통화', '기록', '징후', '빅데이터', '분석', '거대', '시대', '데이터', '공유', '기본', '원칙', '제화', '필요', '빅데이터', '우리', '이모저모', '베트남', '테크', '일군', '하노이', '게이츠', '인터뷰', '데이터', '환경', '스노우플레이크', '관리', '농협', '중앙회', '농업', '빅데이터', '플랫폼', '구축', '프로필', '남우', '국세청', '빅데이터', '센터', '엔비디아', '독식', '토종', '클라우드', '반도체', '연합군', '클라우드', '바디', '워시', '브랜드', '평판', '빅데이터', '분석',  ...

# %%
from collections import Counter

Counter(result) # 입력된 데이터에서 중복 데이터에 대한 빈도수를 표현
Counter(result).most_common() # 중복 데이터에 대한 빈도수를 내림차순으로 정렬하여 튜플로 표현
# Out:
# [('빅데이터', 334),
#  ('데이터', 163),
#  ('분석', 93),
#  ('센터', 82),
#  ('구축', 75),
#  ('브랜드', 70),
#  ('평판', 68),
#  ('결과', 50),
#  ('활용', 48),
#  ('개방', 45),
#  ('기업', 44),
#  ('플랫폼', 43),
#  ('사업', 39),
#  ('스마트', 36),
#  ('카카오', 31),
#  ('바이오', 30),
#  ('공모', 30),
#  ('기술', 29),
#  ('전면', 27),
#  ('기반', 26),
#  ('개최', 24),
#  ('규모', 24),
#  ('장성군', 23),
#  ('디지털', 22),
#  ('경기도', 21),
#  ('건설', 21),
#  ('상장', 21),
#  ('커머스', 20),
#  ('배송비', 20),
#  ('무료', 20),
#  ('선정', 20),
#  ('장성', 18),
#  ('클라우드', 17),
#  ('심평원', 16),
#  ('협약', 16),
#  ('지원', 16),
#  ('의료', 15),
#  ('환자', 15),
#  ('양식', 14),
#  ('지대', 14),
#  ('산업', 14),
#  ('한국', 14),
#  ('개편', 13),
#  ('지자체', 13),
#  ('인공', 13),
#  ('지능', 13),
#  ('사각', 13),
#  ('혁신', 13),
#  ('금융', 13),
#  ('전남', 13),
#  ('포털', 12),
#  ('서울', 12),
#  ('세미나', 12),
#  ('유치', 11),
#  ('복지', 11),
#  ('공개', 10),
#  ('해수부', 10),
#  ('위기', 10),
#  ('투자', 10),
#  ('관광', 10),
#  ('도로공사', 10),
#  ('공모전', 9),
#  ('환경', 9),
#  ('협력', 9),
#  ('행안부', 9),
#  ('아이디어', 9),
#  ('징후', 9),
#  ('솔루션', 9),
#  ('농업', 9),
#  ('대전', 8),
#  ('조달', 8),
#  ('운영', 8),
#  ('현대', 8),
#  ('공인', 8),
#  ('전환', 8),
#  ('테크', 8),
#  ('농협', 8),
#  ('옥천군', 8),
#  ('발굴', 8),
#  ('전남도', 8),
#  ('대응', 7),
#  ('모집', 7),
#  ('추진', 7),
#  ('전문', 7),
#  ('이씨', 7),
#  ('마이너', 7),
#  ('김해시', 7),
#  ('미래', 7),
#  ('제시', 7),
#  ('개발', 7),
#  ('리츠', 7),
#  ('정보', 7),
#  ('건강', 7),
#  ('소상', 7),
#  ('시대', 7),
#  ('유플러스', 7),
#  ('엔터프라이즈', 7),
#  ('이용', 7),
#  ('정책', 7),
#  ('시스템', 6),
#  ('모델', 6),
#  ('특허', 6),
#  ('유망', 6),
#  ('조달청', 6),
#  ('생활', 6),
#  ('스타트업', 6),
#  ('고흥군', 6),
#  ('순천대', 6),
#  ('밸리', 6),
#  ('공공기관', 6),
#  ('유통', 6),
#  ('선두', 6),
#  ('고창군', 6),
#  ('표준', 6),
#  ('엑스', 6),
#  ('전력', 6),
#  ('에스', 6),
#  ('국가', 6),
#  ('컨설팅', 6),
#  ('포항시', 5),
#  ('대기', 5),
#  ('엔비디아', 5),
#  ('진단', 5),
#  ('상명대', 5),
#  ('스케', 5),
#  ('아파트', 5),
#  ('상의', 5),
#  ('물류', 5),
#  ('프리', 5),
#  ('위탁', 5),
#  ('교육', 5),
#  ('기획', 5),
#  ('식품', 5),
#  ('정립', 5),
#  ('로그', 5),
#  ('복제', 5),
#  ('등록', 5),
#  ('서비스', 5),
#  ('착수', 5),
#  ('본격', 5),
#  ('수요', 5),
#  ('제공', 5),
#  ('가수', 5),
#  ('중앙회', 5),
#  ('반도체', 5),
#  ('예측', 5),
#  ('체결', 5),
#  ('올해', 5),
#  ('구미시', 5),
#  ('진흥', 5),
#  ('교통', 4),
#  ('통과', 4),
#  ('신세계', 4),
#  ('삼성', 4),
#  ('전자', 4),
#  ('발표', 4),
#  ('하이엔드', 4),
#  ('정보보호', 4),
#  ('정부', 4),
#  ('서울시', 4),
#  ('발언', 4),
#  ('휴먼', 4),
#  ('전략', 4),
#  ('사회', 4),
#  ('신한카드', 4),
#  ('가구', 4),
#  ('지수', 4),
#  ('에너지', 4),
#  ('중개', 4),
#  ('화재', 4),
#  ('연구개발', 4),
#  ('임영웅', 4),
#  ('베트남', 4),
#  ('관리', 4),
#  ('중구', 4),
#  ('정비', 4),
#  ('통계청', 4),
#  ('국비', 4),
#  ('확보', 4),
#  ('인재', 4),
#  ('국민', 4),
#  ('참여', 4),
#  ('연구자', 4),
#  ('화장품', 4),
#  ('대한민국', 4),
#  ('자치', 4),
#  ('단체', 4),
#  ('투데이', 4),
#  ('랭킹', 4),
#  ('강화', 4),
#  ('설립', 4),
#  ('도정', 4),
#  ('통해', 4),
#  ('산학', 3),
#  ('사이버대', 3),
#  ('학과', 3),
#  ('공공', 3),
#  ('광진구', 3),
#  ('시상식', 3),
#  ('자산', 3),
#  ('광주시', 3),
#  ('업무', 3),
#  ('한수정', 3),
#  ('종자', 3),
#  ('육성', 3),
#  ('선도', 3),
#  ('통운', 3),
#  ('기능', 3),
#  ('이슈', 3),
#  ('촉진', 3),
#  ('리파', 3),
#  ('로드맵', 3),
#  ('트로트', 3),
#  ('차지', 3),
#  ('출발', 3),
#  ('서해안', 3),
#  ('최적', 3),
#  ('거대', 3),
#  ('공유', 3),
#  ('필요', 3),
#  ('인터뷰', 3),
#  ('스노우플레이크', 3),
#  ('독식', 3),
#  ('토종', 3),
#  ('연합군', 3),
#  ('바디', 3),
#  ('워시', 3),
#  ('관련', 3),
#  ('정복', 3),
#  ('코인', 3),
#  ('비트코인', 3),
#  ('리움', 3),
#  ('트렌드', 3),
#  ('대표', 3),
#  ('전북도', 3),
#  ('설문조사', 3),
#  ('진행', 3),
#  ('양성', 3),
#  ('핵심', 3),
#  ('데이', 3),
#  ('플로우', 3),
#  ('의료기기', 3),
#  ('마케팅', 3),
#  ('탄력', 3),
#  ('유일', 3),
#  ('생물공학', 3),
#  ('매출', 3),
#  ('모든', 3),
#  ('민간', 3),
#  ('아기', 3),
#  ('몽디', 3),
#  ('첨단', 3),
#  ('비투', 3),
#  ('플로', 3),
#  ('명분', 3),
#  ('시행', 3),
#  ('부산', 3),
#  ('구글', 3),
#  ('국내', 3),
#  ('리코', 3),
#  ('고용', 3),
#  ('서민', 3),
#  ('방향', 3),
#  ('김한규', 3),
#  ('의원', 3),
#  ('익명', 3),
#  ('활성화', 3),
#  ('자체', 3),
#  ('정기예금', 3),
#  ('우리은행', 3),
#  ('광역', 3),
#  ('광주', 3),
#  ('시내버스', 3),
#  ('창원시', 2),
#  ('예능', 2),
#  ('홍키', 2),
#  ('예비', 2),
#  ('타당성', 2),
#  ('조사', 2),
#  ('그룹', 2),
#  ('영상', 2),
#  ('게시판', 2),
#  ('창원', 2),
#  ('저작권', 2),
#  ('침해', 2),
#  ('종합', 2),
#  ('팩토리', 2),
#  ('택배', 2),
#  ('개인정보', 2),
#  ('개발자', 2),
#  ('컨퍼런스', 2),
#  ('청년', 2),
#  ('이스트소프트', 2),
#  ('준비', 2),
#  ('호평', 2),
#  ('경남', 2),
#  ('수업', 2),
#  ('사례', 2),
#  ('눈길', 2),
#  ('접목', 2),
#  ('렌탈', 2),
#  ('참가', 2),
#  ('주식회사', 2),
#  ('진주', 2),
#  ('밀착', 2),
#  ('도시', 2),
#  ('하락', 2),
#  ('광양', 2),
#  ('노총', 2),
#  ('영암', 2),
#  ('아우토반', 2),
#  ('약국', 2),
#  ('건기', 2),
#  ('상담', 2),
#  ('알고리즘', 2),
#  ('타고', 2),
#  ('성황', 2),
#  ('개시', 2),
#  ('태양광', 2),
#  ('발전소', 2),
#  ('계명대', 2),
#  ('동산의료원', 2),
#  ('애니', 2),
#  ('플러스', 2),
#  ('광고', 2),
#  ('함부로', 2),
#  ('집단소송', 2),
#  ('오픈', 2),
#  ('연체', 2),
#  ('통화', 2),
#  ('기록', 2),
#  ('기본', 2),
#  ('원칙', 2),
#  ('제화', 2),
#  ('우리', 2),
#  ('이모저모', 2),
#  ('일군', 2),
#  ('하노이', 2),
#  ('게이츠', 2),
#  ('프로필', 2),
#  ('남우', 2),
#  ('국세청', 2),
#  ('신임', 2),
#  ('가이드라인', 2),
#  ('국산', 2),
#  ('통계', 2),
#  ('국림', 2),
#  ('신설', 2),
#  ('캐시', 2),
#  ('클래식', 2),
#  ('세상', 2),
#  ('이낙연', 2),
#  ('민주당', 2),
#  ('귀국', 2),
#  ('농수산', 2),
#  ('공사', 2),
#  ('민관', 2),
#  ('신재생에너지', 2),
#  ('전량', 2),
#  ('페넬로페', 2),
#  ('기저귀', 2),
#  ('상명대학교', 2),
#  ('윤석열', 2),
#  ('대통령', 2),
#  ('수능', 2),
#  ('사교육', 2),
#  ('척결', 2),
#  ('배종찬', 2),
#  ('정치', 2),
#  ('접근성', 2),
#  ('지방', 2),
#  ('은행', 2),
#  ('결합', 2),
#  ('의역', 2),
#  ('설명', 2),
#  ('투입', 2),
#  ('속도', 2),
#  ('바스', 2),
#  ('에이치', 2),
#  ('도내', 2),
#  ('통합', 2),
#  ('남면', 2),
#  ('롯데', 2),
#  ('연구', 2),
#  ('국무회의', 2),
#  ('의결', 2),
#  ('가정', 2),
#  ('용품', 2),
#  ('코웨이', 2),
#  ('상품', 2),
#  ('김태영', 2),
#  ('심층', 2),
#  ('오세훈', 2),
#  ('이태원', 2),
#  ('참사', 2),
#  ('당시', 2),
#  ('검색', 2),
#  ('새만금', 2),
#  ('방탄소년단', 2),
#  ('도민', 2),
#  ('우리동네', 2),
#  ('안전', 2),
#  ('박차', 2),
#  ('회계감사', 2),
#  ('감사', 2),
#  ('보증', 2),
#  ('보험', 2),
#  ('연구원', 2),
#  ('유즈', 2),
#  ('케이스', 2),
#  ('가장', 2),
#  ('중요', 2),
#  ('데이터스트림즈', 2),
#  ('해외', 2),
#  ('진출', 2),
#  ('종이', 2),
#  ('목재', 2),
#  ('영풍', 2),
#  ('수상', 2),
#  ('개도국', 2),
#  ('공무원', 2),
#  ('역량', 2),
#  ('연수', 2),
#  ('보건복지부', 2),
#  ('수립', 2),
#  ('규제', 2),
#  ('아토', 2),
#  ('골든플래닛', 2),
#  ('인증', 2),
#  ('아이엠', 2),
#  ('린지', 2),
#  ('주거', 2),
#  ('보건', 2),
#  ('치료', 2),
#  ('시범', 2),
#  ('문화', 2),
#  ('가닥', 2),
#  ('비급', 2),
#  ('진료', 2),
#  ('급여', 2),
#  ('하이닉스', 2),
#  ('메모리', 2),
#  ('섬유', 2),
#  ('의류', 2),
#  ('상공', 2),
#  ('처리', 2),
#  ('라이브러리', 2),
#  ('이찬원', 2),
#  ('사이버', 2),
#  ('대학교', 2),
#  ('조성', 2),
#  ('성형', 2),
#  ('울산', 2),
#  ('노선', 2),
#  ('기관', 2),
#  ('포토', 2),
#  ('사망', 2),
#  ('린다', 2),
#  ('용인시', 1),
#  ('각종', 1),
#  ('접수', 1),
#  ('취업', 1),
#  ('걱정', 1),
#  ('명품', 1),
#  ('학교', 1),
#  ('선일', 1),
#  ('고등학교', 1),
#  ('개선', 1),
#  ('약자', 1),
#  ('장애인', 1),
#  ('동권', 1),
#  ('향상', 1),
#  ('도보', 1),
#  ('내비게이션', 1),
#  ('프로그램', 1),
#  ('퀴즈', 1),
#  ('블럭', 1),
#  ('런닝맨', 1),
#  ('시너지', 1),
#  ('관광지', 1),
#  ('옥천', 1),
#  ('랜섬', 1),
#  ('웨어', 1),
#  ('해킹', 1),
#  ('피해', 1),
#  ('안내면', 1),
#  ('황의조', 1),
#  ('여론', 1),
#  ('충격', 1),
#  ('사생활', 1),
#  ('단계', 1),
#  ('자궁경부암', 1),
#  ('민주화', 1),
#  ('오픈소스', 1),
#  ('코드', 1),
#  ('가야', 1),
#  ('특례시', 1),
#  ('에어컨', 1),
#  ('건보', 1),
#  ('척수', 1),
#  ('손상', 1),
#  ('합병증', 1),
#  ('현황', 1),
#  ('보고서', 1),
#  ('방송인', 1),
#  ('유재석', 1),
#  ('탁재훈', 1),
#  ('업계', 1),
#  ('확산', 1),
#  ('크로스', 1),
#  ('물살', 1),
#  ('김태', 1),
#  ('공언', 1),
#  ('개인', 1),
#  ('간편', 1),
#  ('결제', 1),
#  ('네이버', 1),
#  ('페이', 1),
#  ('내달', 1),
#  ('송장', 1),
#  ('가동', 1),
#  ('수집', 1),
#  ('권리', 1),
#  ('보호', 1),
#  ('균형', 1),
#  ('데브', 1),
#  ('증진', 1),
#  ('도모', 1),
#  ('해운', 1),
#  ('상승', 1),
#  ('분산', 1),
#  ('공기청정기', 1),
#  ('인터넷', 1),
#  ('케이', 1),
#  ('뱅크', 1),
#  ('카카', 1),
#  ('온라인', 1),
#  ('성공', 1),
#  ('보유', 1),
#  ('에이스침대', 1),
#  ('충북도', 1),
#  ('자료', 1),
#  ('범위', 1),
#  ('규정', 1),
#  ('닥터', 1),
#  ('가능', 1),
#  ('상공회의소', 1),
#  ('장비', 1),
#  ('충북', 1),
#  ('올리브', 1),
#  ('네트웍', 1),
#  ('기초', 1),
#  ('심의', 1),
#  ('니아', 1),
#  ('견인', 1),
#  ('순항', 1),
#  ('법안', 1),
#  ('과제', 1),
#  ('스타', 1),
#  ('안정', 1),
#  ('소방청', 1),
#  ('기부', 1),
#  ('학계', 1),
#  ('천군', 1),
#  ('위험', 1),
#  ('신용', 1),
#  ('전시회', 1),
#  ('산업대', 1),
#  ('아태', 1),
#  ('학습', 1),
#  ('전북', 1),
#  ('펀진', 1),
#  ('국방', 1),
#  ('주자', 1),
#  ('대학', 1),
#  ('암호', 1),
#  ('화폐', 1),
#  ('유럽', 1),
#  ('양해', 1),
#  ('유전자', 1),
#  ('실시', 1),
#  ('병원', 1),
#  ('해법', 1),
#  ('모색', 1),
#  ('절실', 1),
#  ('부산시', 1),
#  ('신청', 1),
#  ('김영식', 1),
#  ('회계사', 1),
#  ('회장', 1),
#  ('대형', 1),
#  ('회계법인', 1),
#  ('유물', 1),
#  ('경영', 1),
#  ('희귀', 1),
#  ('질병', 1),
#  ('획득', 1),
#  ('제지', 1),
#  ('글로벌', 1),
#  ('겨냥', 1),
#  ('합의', 1),
#  ('성황리', 1),
#  ('기여', 1),
#  ('브레인', 1),
#  ('편의', 1),
#  ('증대', 1),
#  ('팩토', 1),
#  ('메타', 1),
#  ('버스', 1),
#  ('완성', 1),
#  ('시한', 1),
#  ('아이클라우드', 1),
#  ('토대', 1),
#  ('수면', 1),
#  ('습관', 1),
#  ('청력', 1),
#  ('수준', 1),
#  ('누구', 1),
#  ('유공', 1),
#  ('정통부', 1),
#  ('장관', 1),
#  ('표창', 1),
#  ('비영리단체', 1),
#  ('경쟁력', 1),
#  ('배터리', 1),
#  ('확장', 1),
#  ('걸음', 1),
#  ('빅파마', 1),
#  ('코로나', 1),
#  ('고심', 1),
#  ('신규', 1),
#  ('보고', 1),
#  ('은평구', 1),
#  ('도서관', 1),
#  ('직원', 1),
#  ('해피', 1),
#  ('지역', 1),
#  ('아크릴', 1),
#  ('옵스', 1),
#  ('나단', 1),
#  ('관계자', 1),
#  ('관심', 1),
#  ('집중', 1),
#  ('개막', 1),
#  ('벡스코', 1),
#  ('컨벤션', 1),
#  ('대상', 1),
#  ('불법', 1),
#  ('정차', 1),
#  ('복지부', 1),
#  ('국립', 1),
#  ('공주대', 1),
#  ('기상', 1),
#  ('기후', 1),
#  ('융합', 1),
#  ('특성', 1),
#  ('대학원', 1),
#  ('회사', 1),
#  ('인테리어', 1),
#  ('법적', 1),
#  ('근거', 1),
#  ('마련', 1),
#  ('개정', 1),
#  ('모니터링', 1),
#  ('저축은행', 1),
#  ('가명', 1),
#  ('사용', 1),
#  ('도입', 1),
#  ('박서진', 1),
#  ('양준', 1),
#  ('박지현', 1),
#  ('해양수산부', 1),
#  ('에스티', 1),
#  ('인터', 1),
#  ('성장', 1),
#  ('강원', 1),
#  ('생태계', 1),
#  ('해고', 1),
#  ('비용', 1),
#  ('절감', 1),
#  ('실리콘밸리', 1),
#  ('실률', 1),
#  ('승부', 1),
#  ('장기', 1),
#  ('강태오', 1),
#  ('배우', 1),
#  ('순위', 1),
#  ('이세영', 1),
#  ('이준혁', 1),
#  ('김태리', 1),
#  ('마동', 1),
#  ('고흥', 1),
#  ('수탁', 1),
#  ('논의', 1),
#  ('금융시장', 1),
#  ('진입', 1),
#  ('기준', 1),
#  ('충돌', 1),
#  ('신약', 1),
#  ('쇼케이스', 1),
#  ('맞춤', 1),
#  ('쿼리', 1),
#  ('게임', 1),
#  ('인사이트', 1),
#  ('도출', 1),
#  ('캐리어', 1),
#  ('냉장', 1),
#  ('무인', 1),
#  ('민영화', 1),
#  ('우려', 1),
#  ('복지사', 1),
#  ('하반기', 1),
#  ('중부', 1),
#  ('최대', 1),
#  ('충주', 1),
#  ('박수영', 1),
#  ('민경욱', 1),
#  ('저리', 1),
#  ('저격', 1),
#  ('선관위', 1),
#  ('힐스테이트', 1),
#  ('미소', 1),
#  ('정보기술', 1),
#  ('자동화', 1),
#  ('감독', 1),
#  ('물꼬', 1),
#  ('계속', 1),
#  ('광역시', 1),
#  ('콘텐츠', 1),
#  ('애플', 1),
#  ('비자', 1),
#  ('카드', 1),
#  ('남구', 1),
#  ('중개사', 1),
#  ('위원회', 1),
#  ('올인원', 1),
#  ('침대', 1),
#  ('시몬', 1),
#  ('이케아', 1),
#  ('음원', 1),
#  ('거래', 1),
#  ('아이템', 1),
#  ('경기', 1),
#  ('불황', 1),
#  ('분야', 1),
#  ('쿠션', 1),
#  ('입생로랑', 1),
#  ('디올', 1),
#  ('정샘', 1),
#  ('비만', 1),
#  ('클리', 1),
#  ('경희', 1),
#  ('헬스', 1),
#  ('흡입', 1),
#  ('개정안', 1),
#  ('광장', 1),
#  ('경진', 1),
#  ('대회', 1),
#  ('금융위', 1),
#  ('지정', 1),
#  ('하루', 1)]

# %%
# 글자의 빈도수가 25이하인 데이터는 제외
freq_result = []
for data, c in Counter(result).most_common():
    if c > 25 :
        freq_result.append((data, c))
print(freq_result)
# Out:
# [('빅데이터', 334), ('데이터', 163), ('분석', 93), ('센터', 82), ('구축', 75), ('브랜드', 70), ('평판', 68), ('결과', 50), ('활용', 48), ('개방', 45), ('기업', 44), ('플랫폼', 43), ('사업', 39), ('스마트', 36), ('카카오', 31), ('바이오', 30), ('공모', 30), ('기술', 29), ('전면', 27), ('기반', 26)]

# %% [markdown]
# #### 데이터 시각화
# - 자연어 처리를 위한 텍스트 분석에는 딥 러닝에 기반한 분석 방식을 사용해야함
# - 딥러닝 분석의 기본적인 구조는 언어 패턴을 분석하여 단어와 뜻을 기계에 학습시키는 방식
# - 이는 통계적 구조 및 수학적 수식에 대한 이해가 필요하므로 이 과정에서는 다루지 않음
# - 간단하게 빈도수를 그림으로 나타내는 빈도 막대그래프와 워드 클라우드 라이브러리를 이용해 시각적으로 표현할 예정

# %%
dataList = []
indexList = []
for data, index in freq_result:
    dataList.append(data)
    indexList.append(index)

# 그래프를 노트북 안에 그리기 위해 설정
# %matplotlib inline

# 필요한 패키지와 라이브러리를 가져옴
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
plt.rcParams['axes.unicode_minus'] = False
print ('버전: ', mpl.__version__)
print ('설치 위치: ', mpl.__file__)
print ('설정 위치: ', mpl.get_configdir())
print ('캐시 위치: ', mpl.get_cachedir())
print ('설정 파일 위치: ', mpl.matplotlib_fname())

# 나눔 폰트를 설정하기 전에 캐시 위치에 있는 파일을 삭제할 것
plt.rcParams['font.family'] = "NanumGothic"
print('# 설정되어있는 폰트 사이즈')
print (plt.rcParams['font.size'] ) 
print('# 설정되어있는 폰트 글꼴')
print (plt.rcParams['font.family'] )

plt.title('빅데이터 검색 단어 수')
plt.barh(dataList, indexList)
# Out:
# 버전:  3.7.0
# 설치 위치:  C:\Users\jhmoc\anaconda3\lib\site-packages\matplotlib\__init__.py
# 설정 위치:  C:\Users\jhmoc\.matplotlib
# 캐시 위치:  C:\Users\jhmoc\.matplotlib
# 설정 파일 위치:  C:\Users\jhmoc\anaconda3\lib\site-packages\matplotlib\mpl-data\matplotlibrc
# # 설정되어있는 폰트 사이즈
# 10.0
# # 설정되어있는 폰트 글꼴
# ['NanumGothic']
# <BarContainer object of 20 artists>

# %%
# !pip install wordcloud
# Out:
# Collecting wordcloud
#   Downloading wordcloud-1.9.2-cp310-cp310-win_amd64.whl (152 kB)
#      -------------------------------------- 152.1/152.1 kB 9.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.6.1 in c:\users\jhmoc\anaconda3\lib\site-packages (from wordcloud) (1.23.5)
# Requirement already satisfied: pillow in c:\users\jhmoc\anaconda3\lib\site-packages (from wordcloud) (9.4.0)
# Requirement already satisfied: matplotlib in c:\users\jhmoc\anaconda3\lib\site-packages (from wordcloud) (3.7.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\jhmoc\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.0.5)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\jhmoc\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\jhmoc\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\jhmoc\anaconda3\lib\site-packages (from matplotlib->wordcloud) (22.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\jhmoc\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\jhmoc\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\jhmoc\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\jhmoc\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.2

# %%
from wordcloud import WordCloud
wordcloud = WordCloud(font_path="malgun", 
              background_color="white", 
              width=500, 
              height=500, 
              max_words=100, 
              max_font_size=200)
dataStr = ""
for (data, c) in freq_result:
    dataStr += data + " "
wordcloud.generate(dataStr)
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show()
